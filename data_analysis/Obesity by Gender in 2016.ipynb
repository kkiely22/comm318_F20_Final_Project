# %% [markdown]
# # US Obesity Rate by Gender in 2016
# - This notebook will explore obesity rates for males and females nationally
# - First, the notebook will calculate the national obesity rate
# - Second, the notebook will calculate the average national obesity rate for males and for females
# - Third, the notebook will show a graph comparing the national obesity rates for males and females
# - The purpose of this notebook is to show what gender had the highest obesity rate in 2016

# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as np
import sys
import matplotlib 
import seaborn as sns
import numpy as np

# %% [markdown]
# # Import and Explore Obesity by Gender Data Frame

# %%
obesity_in_US_gender_2016 = pd.read_csv('../data/Clean Data/obesity_in_US_gender_2016.csv')

# %%
obesity_in_US_gender_2016
# Out:
#      Unnamed: 0  year state      state_name  gender_pc  Data_Value_Alt  \
# 0             0  2016    US        National       41.0            41.0
# 1             1  2016    US        National       29.3            29.3
# 2             2  2016    AR        Arkansas       38.0            38.0
# 3             3  2016    AR        Arkansas       27.0            27.0
# 4             4  2016    AL         Alabama       38.2            38.2
# ..          ...   ...   ...             ...        ...             ...
# 215         215  2016    GU            Guam       27.3            27.3
# 216         216  2016    PR     Puerto Rico       30.0            30.0
# 217         217  2016    PR     Puerto Rico       31.4            31.4
# 218         218  2016    VI  Virgin Islands       22.2            22.2
# 219         219  2016    VI  Virgin Islands       41.9            41.9
#
#                                               Question  Sample_Size  Total  \
# ...

# %%
obesity_in_US_gender_2016['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
obesity_in_US_gender_2016['Gender'].value_counts()
# Out:
# Female    110
# Male      110
# Name: Gender, dtype: int64

# %% [markdown]
# # Questions
# #### Question 1: What is the obesity rate for females nationally in 2016?
# - Steps:
#     - make national its own data frame named "gender_obesity_in_US_national_2016_df"
#     - create filter named "females_in_2016_national" to focus on female rows
#     - created filter named 'females_in_2016_national_avg' to calculate the average obesity rate of females           nationally
#
# #### Question 2: What is the obesity rate for males nationally in 2016?
# - Steps:
#     - create filter named "males_in_2016_national" to focus on males
#     - create filter named "males_in_2016_national_avg" to calculate the average obesity rate of males                 nationally
#
# #### Question 3: How do male and female obesity rates compare in 2016?
# - Steps:
#     - create filer named "list_of_dfs" with male and female national average data frames
#     - create filter named "combined_df" to combine male and female data frames
#     - plot averages for male and females on a bar chart
#
# #### Question 4: What state has the highest female obesity rate? What state has the lowest female obesity rate?
# - Steps:
#     - create filter named "females_in_2016_bystate_avg" to calculate the average obesity rate of females by           state
#     - Use "females_in_2016_bystate_avg" filter to show the state by state female obesity rate average on chart
#     - calculate the mean of the gender_pc column grouping by state
#     - sort it in descending order and name the result "females_in_2016"
#     - get the top 5 ranked states and name the result "top5_states"
#     - get the bottom 5 ranked states and name the result "bottom5_states"
#
# #### Question 5: What state has the highest male obesity rate? What state has the lowest male obesity rate?
# - Steps:
#     - create filter named "males_in_2016_bystate_avg" to calculate the average obesity rate of males by state
#     - Use "males_in_2016_bystate_avg" filter to show the state by state male obesity rate average on chart
#     - calculate the mean of the gender_pc column grouping by state
#     - sort it in descending order and name the result "males_in_2016"
#     - get the top 5 ranked states and name the result "top5_states"
#     - get the bottom 5 ranked states and name the result "bottom5_states"

# %% [markdown]
# # Question 1: What is the obesity rate for females nationally in 2016?

# %%
#make national its own data frame named "gender_obesity_in_US_national_2016_df"
gender_obesity_in_US_national_2016_df=obesity_in_US_gender_2016[(obesity_in_US_gender_2016['state_name']=='National')]
gender_obesity_in_US_national_2016_df
# Out:
#      Unnamed: 0  year state state_name  gender_pc  Data_Value_Alt  \
# 0             0  2016    US   National       41.0            41.0
# 1             1  2016    US   National       29.3            29.3
# 110         110  2016    US   National       29.6            29.6
# 111         111  2016    US   National       29.5            29.5
#
#                                               Question  Sample_Size  Total  \
# 0    Percent of adults aged 18 years and older who ...     198440.0    NaN
# 1    Percent of adults aged 18 years and older who ...     240000.0    NaN
# 110  Percent of adults aged 18 years and older who ...     198440.0    NaN
# 111  Percent of adults aged 18 years and older who ...     240000.0    NaN
#
#      Gender GeoLocation  LocationID StratificationCategory1 Stratification1
# 0      Male         NaN          59                  Gender            Male
# 1    Female         NaN          59                  Gender          Female
# ...

# %%
# create filter named "females_in_2016_national" to focus on female rows
females_in_2016_national=gender_obesity_in_US_national_2016_df[(gender_obesity_in_US_national_2016_df['Gender']=='Female')]
females_in_2016_national
# Out:
#      Unnamed: 0  year state state_name  gender_pc  Data_Value_Alt  \
# 1             1  2016    US   National       29.3            29.3
# 111         111  2016    US   National       29.5            29.5
#
#                                               Question  Sample_Size  Total  \
# 1    Percent of adults aged 18 years and older who ...     240000.0    NaN
# 111  Percent of adults aged 18 years and older who ...     240000.0    NaN
#
#      Gender GeoLocation  LocationID StratificationCategory1 Stratification1
# 1    Female         NaN          59                  Gender          Female
# 111  Female         NaN          59                  Gender          Female

# %%
# created filter named 'females_in_2016_national_avg' to calculate the average obesity rate of females nationally
females_in_2016_national_avg=females_in_2016_national['gender_pc'].mean()
females_in_2016_national_avg
# Out:
# 29.4

# %%
# Use "females_in_2016_national_avg" filter to show the national obesity rate average on chart
females_in_2016_national_avg=females_in_2016_national.groupby('Gender')['gender_pc'].mean()
females_in_2016_national_avg
title1='The national female obesity rate average in 2016'
print("{}\n{}".format(title1, '='*len(title1)))
print(females_in_2016_national_avg.sort_values())
# Out:
# The national female obesity rate average in 2016
# ...
# Gender
# Female    29.4
# Name: gender_pc, dtype: float64

# %% [markdown]
# ### Answer: On a national scale, 29.4% of females were obese in 2016.

# %% [markdown]
# # Question 2: What is the obesity rate for males nationally in 2016?

# %%
# create filter named "males_in_2016_national" to focus on males 
males_in_2016_national=gender_obesity_in_US_national_2016_df[(gender_obesity_in_US_national_2016_df['Gender']=='Male')]
males_in_2016_national
# Out:
#      Unnamed: 0  year state state_name  gender_pc  Data_Value_Alt  \
# 0             0  2016    US   National       41.0            41.0
# 110         110  2016    US   National       29.6            29.6
#
#                                               Question  Sample_Size  Total  \
# 0    Percent of adults aged 18 years and older who ...     198440.0    NaN
# 110  Percent of adults aged 18 years and older who ...     198440.0    NaN
#
#     Gender GeoLocation  LocationID StratificationCategory1 Stratification1
# 0     Male         NaN          59                  Gender            Male
# 110   Male         NaN          59                  Gender            Male

# %%
# create filter named "males_in_2016_national_avg" to calculate the average obesity rate of males nationally
males_in_2016_national_avg=males_in_2016_national['gender_pc'].mean()
males_in_2016_national_avg
# Out:
# 35.3

# %%
# Use "males_in_2016_national_avg" filter to calculate the national obesity rate average on chart
males_in_2016_national_avg=males_in_2016_national.groupby('Gender')['gender_pc'].mean()
males_in_2016_national_avg
title1='The national male obesity rate average in 2016'
print("{}\n{}".format(title1, '='*len(title1)))
print(males_in_2016_national_avg.sort_values())
# Out:
# The national male obesity rate average in 2016
# ...
# Gender
# Male    35.3
# Name: gender_pc, dtype: float64

# %% [markdown]
# ### Answer: On a national scale, 35.3% of males were obese in 2016.

# %% [markdown]
# # Question 3: How do male and female obesity rates compare in 2016?

# %%
# create filer named "list_of_dfs" with male and female national average data frames
# create filter named "combined_df" to combine male and female data frames

list_of_dfs = [males_in_2016_national,
               females_in_2016_national]

combined_df = pd.concat(list_of_dfs)

# plot averages for male and females on a bar chart
combined_df.groupby('Gender')['gender_pc'].mean().plot(kind='bar', color= 'green')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %% [markdown]
# - males are more obese than females in 2016

# %% [markdown]
# # **Create a new data frame that only has US states

# %%
## Gender
# Create a data frame named "obesity_in_US_gender_2016" that excludes the rows 
# with the value "National", Guam", "Puerto Rico", "Virgin Islands" in the LocationDesc column
obesity_in_US_gender_2016=obesity_in_US_gender_2016[~(obesity_in_US_gender_2016['state_name']=='National')]
obesity_in_US_gender_2016=obesity_in_US_gender_2016[~(obesity_in_US_gender_2016['state_name']=='Guam')]
obesity_in_US_gender_2016=obesity_in_US_gender_2016[~(obesity_in_US_gender_2016['state_name']=='Puerto Rico')]
obesity_in_US_gender_2016=obesity_in_US_gender_2016[~(obesity_in_US_gender_2016['state_name']=='Virgin Islands')]
obesity_in_US_gender_2016['state_name'].unique()
# Out:
# array(['Arkansas', 'Alabama', 'Alaska', 'Arizona', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# # Question 4: What state has the highest female obesity rate? What state has the lowest female obesity rate?

# %%
# create filter named "females_in_2016_bystate" on "obesity_in_US_gender_2016" to select only females
females_in_2016_bystate=obesity_in_US_gender_2016[(obesity_in_US_gender_2016['Gender']=='Female')]
females_in_2016_bystate
# Out:
#      Unnamed: 0  year state     state_name  gender_pc  Data_Value_Alt  \
# 3             3  2016    AR       Arkansas       27.0            27.0
# 5             5  2016    AL        Alabama       29.5            29.5
# 7             7  2016    AK         Alaska       31.7            31.7
# 9             9  2016    AZ        Arizona       28.9            28.9
# 11           11  2016    CA     California       29.5            29.5
# ..          ...   ...   ...            ...        ...             ...
# 205         205  2016    VA       Virginia       29.5            29.5
# 207         207  2016    WA     Washington       27.7            27.7
# 209         209  2016    WV  West Virginia       37.4            37.4
# 211         211  2016    WI      Wisconsin       29.9            29.9
# 213         213  2016    WY        Wyoming       27.2            27.2
#
#                                               Question  Sample_Size  Total  \
# ...

# %%
# create filter named "females_in_2016_bystate_avg" to calculate the average obesity rate of females by state
females_in_2016_bystate_avg=females_in_2016_bystate['gender_pc'].mean()
females_in_2016_bystate_avg
# Out:
# 29.467647058823523

# %% [markdown]
# ### Answer: The average obesity rate by state for females is 29.5%

# %%
# Use "females_in_2016_bystate_avg" filter to show the state by stae female obesity rate average on chart
females_in_2016_bystate_avg = females_in_2016_bystate.sort_values(['state_name'], ascending = [True])
females_in_2016_bystate_avg=females_in_2016_bystate_avg[['state','state_name','gender_pc','Gender']]
females_in_2016_bystate_avg = females_in_2016_bystate_avg.groupby('state_name')['gender_pc'].mean()
females_in_2016_bystate_avg
# Out:
# state_name
# Alabama                 32.35
# Alaska                  31.00
# Arizona                 28.35
# Arkansas                33.20
# California              27.35
# Colorado                25.15
# Connecticut             27.10
# Delaware                31.50
# District of Columbia    24.75
# Florida                 28.35
# Georgia                 30.95
# Hawaii                  23.95
# Idaho                   28.30
# Illinois                29.25
# Indiana                 31.50
# Iowa                    30.30
# Kansas                  30.05
# Kentucky                32.40
# Louisiana               32.50
# Maine                   29.30
# Maryland                29.85
# Massachusetts           25.90
# Michigan                31.25
# Minnesota               28.00
# Mississippi             34.30
# Missouri                29.90
# Montana                 27.65
# Nebraska                30.90
# Nevada                  27.50
# New Hampshire           27.55
# ...

# %% [markdown]
# ##### Note: This is a state by state breakdown of the average obesity rate for females in 2016

# %%
# 1. Set up the figure to plot bar chart
plt.figure(figsize=(20,4))
plt.subplot

# use the 'females_in_2016_bystate_avg' mean data to plot a bar chart and add labels
females_in_2016_bystate_avg.plot(kind='bar')
plt.xlabel('States')
plt.ylabel('Obesity Rate')
plt.title('Female Obesity Rates by State in 2016')
# Out:
# Text(0.5, 1.0, 'Female Obesity Rates by State in 2016')

# %%
# 1. calculate the mean of the gender_pc column grouping by state 
#    sort it in descending order and name the result "females_in_2016"

# 2. get the top 5 ranked states and name the result "top5_states"

# 3. get the bottom 5 ranked states and name the result "bottom5_states"

females_in_2016=females_in_2016_bystate.groupby('state_name')['gender_pc'].mean().sort_values(ascending=False)
top5_states = females_in_2016.head(5)
bottom5_states = females_in_2016.tail(5)



print("Measuring female obesity rates by state.\n")
print(f"The top 5 states are { ', '.join(top5_states.index)}")
print(f"The bottom 5 states are { ', '.join(bottom5_states.index)}")
females_in_2016.sort_values(ascending=False).to_frame()
# Out:
# Measuring female obesity rates by state.
#
# The top 5 states are Mississippi, Arkansas, West Virginia, Louisiana, Kentucky
# The bottom 5 states are Vermont, Massachusetts, Colorado, District of Columbia, Hawaii
#                       gender_pc
# state_name
# Mississippi               34.30
# Arkansas                  33.20
# West Virginia             33.00
# Louisiana                 32.50
# Kentucky                  32.40
# Alabama                   32.35
# Tennessee                 31.70
# South Carolina            31.65
# Indiana                   31.50
# Delaware                  31.50
# Oklahoma                  31.40
# Michigan                  31.25
# Texas                     31.20
# North Carolina            31.15
# Alaska                    31.00
# Georgia                   30.95
# North Dakota              30.95
# Nebraska                  30.90
# Ohio                      30.90
# Iowa                      30.30
# Virginia                  30.05
# ...

# %% [markdown]
# ### Answer: Mississippi had the highest female obesity rate in 2016 at 34.3% and Hawaii had the lowest female obesity rate in 2016 at 24%

# %% [markdown]
# # Question 5: What state has the highest male obesity rate? What state has the lowest male obesity rate?

# %%
# create filter named "males_in_2016_bystate"
males_in_2016_bystate=obesity_in_US_gender_2016[(obesity_in_US_gender_2016['Gender']=='Male')]
males_in_2016_bystate
# Out:
#      Unnamed: 0  year state     state_name  gender_pc  Data_Value_Alt  \
# 2             2  2016    AR       Arkansas       38.0            38.0
# 4             4  2016    AL        Alabama       38.2            38.2
# 6             6  2016    AK         Alaska       38.3            38.3
# 8             8  2016    AZ        Arizona       39.4            39.4
# 10           10  2016    CA     California       42.4            42.4
# ..          ...   ...   ...            ...        ...             ...
# 204         204  2016    VA       Virginia       28.5            28.5
# 206         206  2016    WA     Washington       29.5            29.5
# 208         208  2016    WV  West Virginia       37.9            37.9
# 210         210  2016    WI      Wisconsin       31.5            31.5
# 212         212  2016    WY        Wyoming       28.2            28.2
#
#                                               Question  Sample_Size  Total  \
# ...

# %%
# create filter named "females_in_2016_bystate_avg" to calculate the average obesity rate of females by state
males_in_2016_bystate_avg=males_in_2016_bystate['gender_pc'].mean()
males_in_2016_bystate_avg
# Out:
# 35.529411764705884

# %% [markdown]
# ### Answer: The average obesity rate by state for males is 35.5%

# %%
# Use "males_in_2016_bystate_avg" filter to show the state by state female obesity rate average on chart
males_in_2016_bystate_avg = males_in_2016_bystate.sort_values(['state_name'], ascending = [True])
males_in_2016_bystate_avg=males_in_2016_bystate_avg[['state','state_name','gender_pc','Gender']]
males_in_2016_bystate_avg = males_in_2016_bystate_avg.groupby('state_name')['gender_pc'].mean()
males_in_2016_bystate_avg
# Out:
# state_name
# Alabama                 37.20
# Alaska                  35.30
# Arizona                 34.80
# Arkansas                35.05
# California              33.65
# Colorado                32.70
# Connecticut             34.65
# Delaware                36.60
# District of Columbia    28.85
# Florida                 34.85
# Georgia                 34.85
# Hawaii                  33.40
# Idaho                   36.05
# Illinois                35.85
# Indiana                 35.60
# Iowa                    38.15
# Kansas                  36.45
# Kentucky                36.65
# Louisiana               36.75
# Maine                   35.90
# Maryland                34.70
# Massachusetts           34.25
# Michigan                36.20
# Minnesota               36.50
# Mississippi             37.05
# Missouri                37.30
# Montana                 34.75
# Nebraska                37.50
# Nevada                  34.55
# New Hampshire           35.70
# ...

# %% [markdown]
# ##### Note: This is a state by state breakdown of the average obesity rate for males in 2016

# %%
# 1. Set up the figure to plot bar chart
plt.figure(figsize=(20,4))
plt.subplot

# use the 'males_in_2016_bystate_avg' mean data to plot a bar chart and add labels
males_in_2016_bystate_avg.plot(kind='bar')
plt.xlabel('States')
plt.ylabel('Obesity Rate')
plt.title('Male Obesity Rates by State in 2016')
# Out:
# Text(0.5, 1.0, 'Male Obesity Rates by State in 2016')

# %%
# 1. calculate the mean of the gender_pc column grouping by state 
#    sort it in descending order and name the result "males_in_2016"

# 2. get the top 5 ranked states and name the result "top5_states"

# 3. get the bottom 5 ranked states and name the result "bottom5_states"

males_in_2016=males_in_2016_bystate.groupby('state_name')['gender_pc'].mean().sort_values(ascending=False)
top5_states = males_in_2016.head(5)
bottom5_states = males_in_2016.tail(5)



print("Measuring male obesity rates by state.\n")
print(f"The top 5 states are { ', '.join(top5_states.index)}")
print(f"The bottom 5 states are { ', '.join(bottom5_states.index)}")
males_in_2016.sort_values(ascending=False).to_frame()
# Out:
# Measuring male obesity rates by state.
#
# The top 5 states are Iowa, West Virginia, Nebraska, Missouri, Oklahoma
# The bottom 5 states are California, New York, Hawaii, Colorado, District of Columbia
#                       gender_pc
# state_name
# Iowa                      38.15
# West Virginia             37.85
# Nebraska                  37.50
# Missouri                  37.30
# Oklahoma                  37.30
# Alabama                   37.20
# Mississippi               37.05
# Texas                     37.00
# Tennessee                 36.90
# South Dakota              36.90
# North Dakota              36.80
# Louisiana                 36.75
# Kentucky                  36.65
# Delaware                  36.60
# Minnesota                 36.50
# Kansas                    36.45
# Michigan                  36.20
# Wisconsin                 36.10
# Idaho                     36.05
# New Jersey                36.05
# Maine                     35.90
# Illinois                  35.85
# ...

# %% [markdown]
# ### Answer: Iowa had the highest male obesity rate in 2016 at 38.15% and Colorado had the lowest male obesity rate in 2016 at 32.7%

# %% [markdown]
# # Conclusion
#
# ## Female Obesity Rate:
# - On a national scale, 29.4% of females were obese in 2016.
# - Mississippi had the highest female obesity rate in 2016 at 34.3% and Hawaii had the lowest female obesity rate in 2016 at 24%
#
# ## Male Obesity Rate:
# - On a national scale, 35.3% of males were obese in 2016.
# - Iowa had the highest male obesity rate in 2016 at 38.15% and Colorado had the lowest male obesity rate in 2016 at 32.7%
