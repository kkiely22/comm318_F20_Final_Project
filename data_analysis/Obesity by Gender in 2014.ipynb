# %% [markdown]
# # US Obesity Rate by Gender in 2014
# - This notebook will explore obesity rates for males and females nationally
# - First, the notebook will calculate the national obesity rate
# - Second, the notebook will calculate the average national obesity rate for males and for females
# - Third, the notebook will show a graph comparing the national obesity rates for males and females
# - The purpose of this notebook is to show what gender had the highest obesity rate in 2014

# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as np
import sys
import matplotlib 
import seaborn as sns
import numpy as np

# %% [markdown]
# # Import and Explore Obesity by Gender Data Frame

# %%
obesity_in_US_gender_2014 = pd.read_csv('../data/Clean Data/obesity_in_US_gender_2014.csv')

# %%
obesity_in_US_gender_2014
# Out:
#      Unnamed: 0  year state state_name  gender_pc  Data_Value_Alt  \
# 0             0  2014    AL    Alabama       32.9            32.9
# 1             1  2014    AL    Alabama       34.1            34.1
# 2             2  2014    AL    Alabama       37.2            37.2
# 3             3  2014    AL    Alabama       29.8            29.8
# 4             4  2014    AK     Alaska       29.3            29.3
# ..          ...   ...   ...        ...        ...             ...
# 211         211  2014    WI  Wisconsin       29.6            29.6
# 212         212  2014    WY    Wyoming       29.7            29.7
# 213         213  2014    WY    Wyoming       29.2            29.2
# 214         214  2014    WY    Wyoming       41.7            41.7
# 215         215  2014    WY    Wyoming       27.8            27.8
#
#                                               Question  Sample_Size  Total  \
# 0    Percent of adults aged 18 years and older who ...       5156.0    NaN
# ...

# %%
obesity_in_US_gender_2014['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
obesity_in_US_gender_2014['Gender'].value_counts()
# Out:
# Male      108
# Female    108
# Name: Gender, dtype: int64

# %% [markdown]
# # Questions
# #### Question 1: What is the obesity rate for females nationally in 2014?
# - Steps:
#     - make national its own data frame named "gender_obesity_in_US_national_2014_df"
#     - create filter named "females_in_2014_national" to focus on female rows
#     - created filter named 'females_in_2014_national_avg' to calculate the average obesity rate of females           nationally
#
# #### Question 2: What is the obesity rate for males nationally in 2014?
# - Steps:
#     - create filter named "males_in_2014_national" to focus on males
#     - create filter named "males_in_2014_national_avg" to calculate the average obesity rate of males                 nationally
#
# #### Question 3: How do male and female obesity rates compare in 2014?
# - Steps:
#     - create filer named "list_of_dfs" with male and female national average data frames
#     - create filter named "combined_df" to combine male and female data frames
#     - plot averages for male and females on a bar chart
#
# #### Question 4: What state has the highest female obesity rate? What state has the lowest female obesity rate?
# - Steps:
#     - create filter named "females_in_2014_bystate_avg" to calculate the average obesity rate of females by           state
#     - Use "females_in_2014_bystate_avg" filter to show the state by state female obesity rate average on chart
#     - calculate the mean of the gender_pc column grouping by state
#     - sort it in descending order and name the result "females_in_2014"
#     - get the top 5 ranked states and name the result "top5_states"
#     - get the bottom 5 ranked states and name the result "bottom5_states"
#
# #### Question 5: What state has the highest male obesity rate? What state has the lowest male obesity rate?
# - Steps:
#     - create filter named "males_in_2014_bystate_avg" to calculate the average obesity rate of males by state
#     - Use "males_in_2014_bystate_avg" filter to show the state by state male obesity rate average on chart
#     - calculate the mean of the gender_pc column grouping by state
#     - sort it in descending order and name the result "males_in_2014"
#     - get the top 5 ranked states and name the result "top5_states"
#     - get the bottom 5 ranked states and name the result "bottom5_states"

# %% [markdown]
# # Question 1: What is the obesity rate for females nationally in 2014?

# %%
#make national its own data frame named "gender_obesity_in_US_national_2014_df"
gender_obesity_in_US_national_2014_df=obesity_in_US_gender_2014[(obesity_in_US_gender_2014['state_name']=='National')]
gender_obesity_in_US_national_2014_df
# Out:
#      Unnamed: 0  year state state_name  gender_pc  Data_Value_Alt  \
# 112         112  2014    US   National       29.0            29.0
# 113         113  2014    US   National       28.8            28.8
# 114         114  2014    US   National       41.1            41.1
# 115         115  2014    US   National       29.2            29.2
#
#                                               Question  Sample_Size  Total  \
# 112  Percent of adults aged 18 years and older who ...     183706.0    NaN
# 113  Percent of adults aged 18 years and older who ...     242169.0    NaN
# 114  Percent of adults aged 18 years and older who ...     183706.0    NaN
# 115  Percent of adults aged 18 years and older who ...     242169.0    NaN
#
#      Gender GeoLocation  LocationID StratificationCategory1 Stratification1
# 112    Male         NaN          59                  Gender            Male
# 113  Female         NaN          59                  Gender          Female
# ...

# %%
# create filter named "females_in_2014_national" to focus on female rows
females_in_2014_national=gender_obesity_in_US_national_2014_df[(gender_obesity_in_US_national_2014_df['Gender']=='Female')]
females_in_2014_national
# Out:
#      Unnamed: 0  year state state_name  gender_pc  Data_Value_Alt  \
# 113         113  2014    US   National       28.8            28.8
# 115         115  2014    US   National       29.2            29.2
#
#                                               Question  Sample_Size  Total  \
# 113  Percent of adults aged 18 years and older who ...     242169.0    NaN
# 115  Percent of adults aged 18 years and older who ...     242169.0    NaN
#
#      Gender GeoLocation  LocationID StratificationCategory1 Stratification1
# 113  Female         NaN          59                  Gender          Female
# 115  Female         NaN          59                  Gender          Female

# %%
# created filter named 'females_in_2014_national_avg' to calculate the average obesity rate of females nationally
females_in_2014_national_avg=females_in_2014_national['gender_pc'].mean()
females_in_2014_national_avg
# Out:
# 29.0

# %%
# Use "females_in_2014_national_avg" filter to show the national obesity rate average on chart
females_in_2014_national_avg=females_in_2014_national.groupby('Gender')['gender_pc'].mean()
females_in_2014_national_avg
title1='The national female obesity rate average in 2014'
print("{}\n{}".format(title1, '='*len(title1)))
print(females_in_2014_national_avg.sort_values())
# Out:
# The national female obesity rate average in 2014
# ...
# Gender
# Female    29.0
# Name: gender_pc, dtype: float64

# %% [markdown]
# ### Answer: On a national scale, 29% of females were obese in 2014.

# %% [markdown]
# # Question 2: What is the obesity rate for males nationally in 2014?

# %%
# create filter named "males_in_2014_national" to focus on males 
males_in_2014_national=gender_obesity_in_US_national_2014_df[(gender_obesity_in_US_national_2014_df['Gender']=='Male')]
males_in_2014_national
# Out:
#      Unnamed: 0  year state state_name  gender_pc  Data_Value_Alt  \
# 112         112  2014    US   National       29.0            29.0
# 114         114  2014    US   National       41.1            41.1
#
#                                               Question  Sample_Size  Total  \
# 112  Percent of adults aged 18 years and older who ...     183706.0    NaN
# 114  Percent of adults aged 18 years and older who ...     183706.0    NaN
#
#     Gender GeoLocation  LocationID StratificationCategory1 Stratification1
# 112   Male         NaN          59                  Gender            Male
# 114   Male         NaN          59                  Gender            Male

# %%
# create filter named "males_in_2014_national_avg" to calculate the average obesity rate of males nationally
males_in_2014_national_avg=males_in_2014_national['gender_pc'].mean()
males_in_2014_national_avg
# Out:
# 35.05

# %%
# Use "males_in_2014_national_avg" filter to calculate the national obesity rate average on chart
males_in_2014_national_avg=males_in_2014_national.groupby('Gender')['gender_pc'].mean()
males_in_2014_national_avg
title1='The national male obesity rate average in 2014'
print("{}\n{}".format(title1, '='*len(title1)))
print(males_in_2014_national_avg.sort_values())
# Out:
# The national male obesity rate average in 2014
# ...
# Gender
# Male    35.05
# Name: gender_pc, dtype: float64

# %% [markdown]
# ### Answer: On a national scale, 35.1% of males were obese in 2014.

# %% [markdown]
# # Question 3: How do male and female obesity rates compare in 2014?

# %%
# create filer named "list_of_dfs" with male and female national average data frames
# create filter named "combined_df" to combine male and female data frames

list_of_dfs = [males_in_2014_national,
               females_in_2014_national]

combined_df = pd.concat(list_of_dfs)

# %%
# plot averages for male and females on a bar chart
combined_df.groupby('Gender')['gender_pc'].mean().plot(kind='bar', color= 'blue')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %% [markdown]
# - Males are more obese than females in 2014

# %% [markdown]
# # **Create a new data frame that only has US states

# %%
## Gender
# Create a data frame named "obesity_in_US_gender_2014" that excludes the rows 
# with the value "National", Guam", "Puerto Rico", "Virgin Islands" in the LocationDesc column
obesity_in_US_gender_2014=obesity_in_US_gender_2014[~(obesity_in_US_gender_2014['state_name']=='National')]
obesity_in_US_gender_2014=obesity_in_US_gender_2014[~(obesity_in_US_gender_2014['state_name']=='Guam')]
obesity_in_US_gender_2014=obesity_in_US_gender_2014[~(obesity_in_US_gender_2014['state_name']=='Puerto Rico')]
obesity_in_US_gender_2014=obesity_in_US_gender_2014[~(obesity_in_US_gender_2014['state_name']=='Virgin Islands')]
obesity_in_US_gender_2014['state_name'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida',
#        'District of Columbia', 'Georgia', 'Hawaii', 'Idaho', 'Illinois',
#        'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine',
#        'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nevada', 'Nebraska',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# # Question 4: What state has the highest female obesity rate? What state has the lowest female obesity rate?

# %%
# create filter named "females_in_2014_bystate" on "obesity_in_US_gender_2014" to select only females
females_in_2014_bystate=obesity_in_US_gender_2014[(obesity_in_US_gender_2014['Gender']=='Female')]
females_in_2014_bystate
# Out:
#      Unnamed: 0  year state     state_name  gender_pc  Data_Value_Alt  \
# 0             0  2014    AL        Alabama       32.9            32.9
# 3             3  2014    AL        Alabama       29.8            29.8
# 5             5  2014    AK         Alaska       30.2            30.2
# 7             7  2014    AK         Alaska       29.4            29.4
# 9             9  2014    AZ        Arizona       28.8            28.8
# ..          ...   ...   ...            ...        ...             ...
# 207         207  2014    WV  West Virginia       28.5            28.5
# 209         209  2014    WI      Wisconsin       30.5            30.5
# 211         211  2014    WI      Wisconsin       29.6            29.6
# 213         213  2014    WY        Wyoming       29.2            29.2
# 215         215  2014    WY        Wyoming       27.8            27.8
#
#                                               Question  Sample_Size  Total  \
# ...

# %%
# create filter named "females_in_2014_bystate_avg" to calculate the average obesity rate of females by state
females_in_2014_bystate_avg=females_in_2014_bystate['gender_pc'].mean()
females_in_2014_bystate_avg
# Out:
# 29.204901960784316

# %% [markdown]
# ### Answer: The average obesity rate by state for females is 29.2%

# %%
# Use "females_in_2014_bystate_avg" filter to show the state by stae female obesity rate average on chart
females_in_2014_bystate_avg = females_in_2014_bystate.sort_values(['state_name'], ascending = [True])
females_in_2014_bystate_avg=females_in_2014_bystate_avg[['state','state_name','gender_pc','Gender']]
females_in_2014_bystate_avg = females_in_2014_bystate_avg.groupby('state_name')['gender_pc'].mean()
females_in_2014_bystate_avg
# Out:
# state_name
# Alabama                 31.35
# Alaska                  29.80
# Arizona                 29.15
# Arkansas                32.80
# California              26.50
# Colorado                24.60
# Connecticut             27.05
# Delaware                31.55
# District of Columbia    26.90
# Florida                 28.05
# Georgia                 30.40
# Hawaii                  24.65
# Idaho                   29.40
# Illinois                29.65
# Indiana                 31.10
# Iowa                    30.05
# Kansas                  29.95
# Kentucky                31.05
# Louisiana               32.25
# Maine                   28.70
# Maryland                30.70
# Massachusetts           25.55
# Michigan                29.90
# Minnesota               27.85
# Mississippi             34.45
# Missouri                29.70
# Montana                 27.65
# Nebraska                29.60
# Nevada                  26.40
# New Hampshire           27.15
# ...

# %% [markdown]
# ##### Note: This is a state by state breakdown of the average obesity rate for females in 2014

# %%
# 1. Set up the figure to plot bar chart
plt.figure(figsize=(20,4))
plt.subplot

# use the 'females_in_2014_bystate_avg' mean data to plot a bar chart and add labels
females_in_2014_bystate_avg.plot(kind='bar')
plt.xlabel('States')
plt.ylabel('Obesity Rate')
plt.title('Female Obesity Rates by State in 2014')
# Out:
# Text(0.5, 1.0, 'Female Obesity Rates by State in 2014')

# %%
# 1. calculate the mean of the gender_pc column grouping by state 
#    sort it in descending order and name the result "females_in_2014"

# 2. get the top 5 ranked states and name the result "top5_states"

# 3. get the bottom 5 ranked states and name the result "bottom5_states"

females_in_2014=females_in_2014_bystate.groupby('state_name')['gender_pc'].mean().sort_values(ascending=False)
top5_states = females_in_2014.head(5)
bottom5_states = females_in_2014.tail(5)



print("Measuring female obesity rates by state.\n")
print(f"The top 5 states are { ', '.join(top5_states.index)}")
print(f"The bottom 5 states are { ', '.join(bottom5_states.index)}")
females_in_2014.sort_values(ascending=False).to_frame()
# Out:
# Measuring female obesity rates by state.
#
# The top 5 states are Mississippi, Arkansas, West Virginia, Louisiana, Oklahoma
# The bottom 5 states are Nevada, Vermont, Massachusetts, Hawaii, Colorado
#                       gender_pc
# state_name
# Mississippi               34.45
# Arkansas                  32.80
# West Virginia             32.25
# Louisiana                 32.25
# Oklahoma                  31.55
# Delaware                  31.55
# Alabama                   31.35
# Tennessee                 31.30
# South Carolina            31.20
# Indiana                   31.10
# Kentucky                  31.05
# Ohio                      30.85
# Maryland                  30.70
# Texas                     30.55
# North Carolina            30.40
# Georgia                   30.40
# New Mexico                30.15
# North Dakota              30.10
# Wisconsin                 30.05
# Iowa                      30.05
# Kansas                    29.95
# Virginia                  29.90
# ...

# %% [markdown]
# ### Answer: Mississippi had the highest female obesity rate in 2014 at 34.45% and Colorado had the lowest female obesity rate in 2014 at 24.6%

# %% [markdown]
# # Question 5: What state has the highest male obesity rate? What state has the lowest male obesity rate?

# %%
# create filter named "males_in_2014_bystate"
males_in_2014_bystate=obesity_in_US_gender_2014[(obesity_in_US_gender_2014['Gender']=='Male')]
males_in_2014_bystate
# Out:
#      Unnamed: 0  year state     state_name  gender_pc  Data_Value_Alt  \
# 1             1  2014    AL        Alabama       34.1            34.1
# 2             2  2014    AL        Alabama       37.2            37.2
# 4             4  2014    AK         Alaska       29.3            29.3
# 6             6  2014    AK         Alaska       40.1            40.1
# 8             8  2014    AZ        Arizona       29.1            29.1
# ..          ...   ...   ...            ...        ...             ...
# 206         206  2014    WV  West Virginia       39.3            39.3
# 208         208  2014    WI      Wisconsin       31.8            31.8
# 210         210  2014    WI      Wisconsin       42.7            42.7
# 212         212  2014    WY        Wyoming       29.7            29.7
# 214         214  2014    WY        Wyoming       41.7            41.7
#
#                                               Question  Sample_Size  Total  \
# ...

# %%
# create filter named "females_in_2014_bystate_avg" to calculate the average obesity rate of females by state
males_in_2014_bystate_avg=males_in_2014_bystate['gender_pc'].mean()
males_in_2014_bystate_avg
# Out:
# 35.244117647058815

# %% [markdown]
# ### Answer: The average obesity rate by state for males is 35.2%

# %%
# Use "males_in_2014_bystate_avg" filter to show the state by state female obesity rate average on chart
males_in_2014_bystate_avg = males_in_2014_bystate.sort_values(['state_name'], ascending = [True])
males_in_2014_bystate_avg=males_in_2014_bystate_avg[['state','state_name','gender_pc','Gender']]
males_in_2014_bystate_avg = males_in_2014_bystate_avg.groupby('state_name')['gender_pc'].mean()
males_in_2014_bystate_avg
# Out:
# state_name
# Alabama                 35.65
# Alaska                  34.70
# Arizona                 34.75
# Arkansas                37.80
# California              33.10
# Colorado                32.55
# Connecticut             33.35
# Delaware                35.90
# District of Columbia    28.10
# Florida                 34.20
# Georgia                 35.35
# Hawaii                  33.20
# Idaho                   36.20
# Illinois                34.20
# Indiana                 35.35
# Iowa                    36.75
# Kansas                  35.90
# Kentucky                35.60
# Louisiana               36.70
# Maine                   35.75
# Maryland                34.25
# Massachusetts           33.35
# Michigan                35.70
# Minnesota               36.00
# Mississippi             36.25
# Missouri                35.80
# Montana                 35.05
# Nebraska                36.90
# Nevada                  36.70
# New Hampshire           36.30
# ...

# %% [markdown]
# ##### Note: This is a state by state breakdown of the average obesity rate for males in 2014

# %%
# 1. Set up the figure to plot bar chart
plt.figure(figsize=(20,4))
plt.subplot

# use the 'males_in_2014_bystate_avg' mean data to plot a bar chart and add labels
males_in_2014_bystate_avg.plot(kind='bar')
plt.xlabel('States')
plt.ylabel('Obesity Rate')
plt.title('Male Obesity Rates by State in 2014')
# Out:
# Text(0.5, 1.0, 'Male Obesity Rates by State in 2014')

# %%
# 1. calculate the mean of the gender_pc column grouping by state 
#    sort it in descending order and name the result "males_in_2014"

# 2. get the top 5 ranked states and name the result "top5_states"

# 3. get the bottom 5 ranked states and name the result "bottom5_states"

males_in_2014=males_in_2014_bystate.groupby('state_name')['gender_pc'].mean().sort_values(ascending=False)
top5_states = males_in_2014.head(5)
bottom5_states = males_in_2014.tail(5)



print("Measuring male obesity rates by state.\n")
print(f"The top 5 states are { ', '.join(top5_states.index)}")
print(f"The bottom 5 states are { ', '.join(bottom5_states.index)}")
males_in_2014.sort_values(ascending=False).to_frame()
# Out:
# Measuring male obesity rates by state.
#
# The top 5 states are North Dakota, Arkansas, West Virginia, Wisconsin, Texas
# The bottom 5 states are Hawaii, California, Utah, Colorado, District of Columbia
#                       gender_pc
# state_name
# North Dakota              38.25
# Arkansas                  37.80
# West Virginia             37.30
# Wisconsin                 37.25
# Texas                     37.15
# Nebraska                  36.90
# Iowa                      36.75
# Nevada                    36.70
# Louisiana                 36.70
# Oklahoma                  36.65
# New Hampshire             36.30
# Mississippi               36.25
# Idaho                     36.20
# South Dakota              36.10
# Minnesota                 36.00
# Kansas                    35.90
# Ohio                      35.90
# Delaware                  35.90
# South Carolina            35.85
# Tennessee                 35.85
# Missouri                  35.80
# Maine                     35.75
# ...

# %% [markdown]
# ### Answer: North Dakota had the highest male obesity rate in 2014 at 38.25% and Colorado had the lowest male obesity rate in 2014 at 32.25%

# %% [markdown]
# # Conclusion
#
# ## Female Obesity Rate:
# - On a national scale, 29% of females were obese in 2014
# - Mississippi had the highest female obesity rate in 2014 at 34.45% and Colorado had the lowest female obesity rate in 2014 at 24.6%
#
# ## Male Obesity Rate:
# - On a national scale, 35.1% of males were obese in 2014.
# - North Dakota had the highest male obesity rate in 2014 at 38.25% and Colorado had the lowest male obesity rate in 2014 at 32.25%
