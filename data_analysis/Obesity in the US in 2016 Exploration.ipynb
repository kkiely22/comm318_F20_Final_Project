# %% [markdown]
# # Obesity in the US 2016 Exploration
# - This is a dataset that looks at adults 18 years and older across the United States who are obese.
# - This data differentiates people by age, income, education, gender, and race/ethnicity.
# - In this notebook, I will explore and clean the dataset and create new data frames for deeper analysis
#     - I will clean up the columns and filter out the year column to only look at 2016 for age, income, education,
#     gender, and race/ethnicity.
#     - I will make data frames for gender obesity rates in 2016, age obesity rates in 2016, income obesity rates in     2016, and education obesity rates in 2016

# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as np
import sys
import matplotlib 
import seaborn as sns
import numpy as np

# %% [markdown]
# # Load & Inspect Data

# %%
obesity_in_US_df = pd.read_csv('../data/Raw Data/Nutrition_Physical_Activity_and_Obesity_Behavioral_Risk_Factor_Surveillance_System.csv')
obesity_in_US_df.shape
# Out:
# (53392, 33)

# %% [markdown]
# # Make a 2016 Data frame

# %%
# dropping unnecessary columns
# rename Stratication1 and StratificationCategory1 and grouping age, education, income, gender, race/ethnicity into columns

obesity_in_US_cols = obesity_in_US_df.drop(['Low_Confidence_Limit','High_Confidence_Limit ','YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1'],1);

#Focusing only on 2016
#create filter 
obesity_in_US_year2016=obesity_in_US_cols[obesity_in_US_cols['YearStart']==2016]
obesity_in_US_year2016
# Out:
#        YearStart LocationAbbr    LocationDesc  \
# 48772       2016           US        National
# 48773       2016           US        National
# 48774       2016           US        National
# 48775       2016           US        National
# 48776       2016           US        National
# ...          ...          ...             ...
# 53387       2016           VI  Virgin Islands
# 53388       2016           VI  Virgin Islands
# 53389       2016           VI  Virgin Islands
# 53390       2016           VI  Virgin Islands
# 53391       2016           VI  Virgin Islands
#
#                                                 Question  Data_Value  \
# 48772  Percent of adults aged 18 years and older who ...        35.2
# 48773  Percent of adults aged 18 years and older who ...        41.0
# 48774  Percent of adults aged 18 years and older who ...        29.3
# 48775  Percent of adults aged 18 years and older who ...        34.7
# 48776  Percent of adults aged 18 years and older who ...        34.2
# ...                                                  ...         ...
# 53387  Percent of adults who engage in no leisure-tim...         NaN
# 53388  Percent of adults who engage in no leisure-tim...         NaN
# 53389  Percent of adults who engage in no leisure-tim...         NaN
# 53390  Percent of adults who engage in no leisure-tim...         NaN
# 53391  Percent of adults who engage in no leisure-tim...         NaN
#
#        Data_Value_Alt  Sample_Size  Total Age(years)              Education  \
# 48772            35.2     438479.0  Total        NaN                    NaN
# 48773            41.0     198440.0    NaN        NaN                    NaN
# 48774            29.3     240000.0    NaN        NaN                    NaN
# 48775            34.7      32325.0    NaN        NaN  Less than high school
# 48776            34.2     123241.0    NaN        NaN   High school graduate
# ...               ...          ...    ...        ...                    ...
# 53387             NaN          NaN    NaN        NaN                    NaN
# 53388             NaN          NaN    NaN        NaN                    NaN
# 53389             NaN          NaN    NaN        NaN                    NaN
# 53390             NaN          NaN    NaN        NaN                    NaN
# 53391             NaN          NaN    NaN        NaN                    NaN
#
#        Gender Income                 Race/Ethnicity              GeoLocation  \
# 48772     NaN    NaN                            NaN                      NaN
# 48773    Male    NaN                            NaN                      NaN
# 48774  Female    NaN                            NaN                      NaN
# 48775     NaN    NaN                            NaN                      NaN
# 48776     NaN    NaN                            NaN                      NaN
# ...       ...    ...                            ...                      ...
# 53387     NaN    NaN                          Asian  (18.335765, -64.896335)
# 53388     NaN    NaN      Hawaiian/Pacific Islander  (18.335765, -64.896335)
# 53389     NaN    NaN  American Indian/Alaska Native  (18.335765, -64.896335)
# 53390     NaN    NaN                2 or more races  (18.335765, -64.896335)
# 53391     NaN    NaN                          Other  (18.335765, -64.896335)
#
#        LocationID StratificationCategory1                Stratification1
# 48772          59                   Total                          Total
# 48773          59                  Gender                           Male
# 48774          59                  Gender                         Female
# 48775          59               Education          Less than high school
# 48776          59               Education           High school graduate
# ...           ...                     ...                            ...
# 53387          78          Race/Ethnicity                          Asian
# 53388          78          Race/Ethnicity      Hawaiian/Pacific Islander
# 53389          78          Race/Ethnicity  American Indian/Alaska Native
# 53390          78          Race/Ethnicity                2 or more races
# 53391          78          Race/Ethnicity                          Other
#
# [4620 rows x 17 columns]

# %%
# create filter that chooses the following questions: 
# filter uses obesity_in_US_year2014 because we are only looking at 2016
       #q1: 'Percent of adults aged 18 years and older who have obesity',
       #q2: 'Percent of adults aged 18 years and older who have an overweight classification'
questions_filter=obesity_in_US_year2016[(obesity_in_US_year2016['Question']=='Percent of adults aged 18 years and older who have obesity') | (obesity_in_US_year2016['Question']=='Percent of adults aged 18 years and older who have an overweight classification')]
questions_filter['Question'].unique()
# Out:
# array(['Percent of adults aged 18 years and older who have an overweight classification',
#        'Percent of adults aged 18 years and older who have obesity'],
#       dtype=object)

# %%
# Rename "questions_filter" to "obesity_in_US_df3"
obesity_in_US_df4 = questions_filter
obesity_in_US_df4
# Out:
#        YearStart LocationAbbr    LocationDesc  \
# 48772       2016           US        National
# 48773       2016           US        National
# 48774       2016           US        National
# 48775       2016           US        National
# 48776       2016           US        National
# ...          ...          ...             ...
# 51847       2016           VI  Virgin Islands
# 51848       2016           VI  Virgin Islands
# 51849       2016           VI  Virgin Islands
# 51850       2016           VI  Virgin Islands
# 51851       2016           VI  Virgin Islands
#
#                                                 Question  Data_Value  \
# 48772  Percent of adults aged 18 years and older who ...        35.2
# 48773  Percent of adults aged 18 years and older who ...        41.0
# 48774  Percent of adults aged 18 years and older who ...        29.3
# 48775  Percent of adults aged 18 years and older who ...        34.7
# 48776  Percent of adults aged 18 years and older who ...        34.2
# ...                                                  ...         ...
# 51847  Percent of adults aged 18 years and older who ...         NaN
# 51848  Percent of adults aged 18 years and older who ...         NaN
# 51849  Percent of adults aged 18 years and older who ...         NaN
# 51850  Percent of adults aged 18 years and older who ...         NaN
# 51851  Percent of adults aged 18 years and older who ...         NaN
#
#        Data_Value_Alt  Sample_Size  Total Age(years)              Education  \
# 48772            35.2     438479.0  Total        NaN                    NaN
# 48773            41.0     198440.0    NaN        NaN                    NaN
# 48774            29.3     240000.0    NaN        NaN                    NaN
# 48775            34.7      32325.0    NaN        NaN  Less than high school
# 48776            34.2     123241.0    NaN        NaN   High school graduate
# ...               ...          ...    ...        ...                    ...
# 51847             NaN          NaN    NaN        NaN                    NaN
# 51848             NaN          NaN    NaN        NaN                    NaN
# 51849             NaN          NaN    NaN        NaN                    NaN
# 51850             NaN          NaN    NaN        NaN                    NaN
# 51851             NaN          NaN    NaN        NaN                    NaN
#
#        Gender Income                 Race/Ethnicity              GeoLocation  \
# 48772     NaN    NaN                            NaN                      NaN
# 48773    Male    NaN                            NaN                      NaN
# 48774  Female    NaN                            NaN                      NaN
# 48775     NaN    NaN                            NaN                      NaN
# 48776     NaN    NaN                            NaN                      NaN
# ...       ...    ...                            ...                      ...
# 51847     NaN    NaN                          Asian  (18.335765, -64.896335)
# 51848     NaN    NaN      Hawaiian/Pacific Islander  (18.335765, -64.896335)
# 51849     NaN    NaN  American Indian/Alaska Native  (18.335765, -64.896335)
# 51850     NaN    NaN                2 or more races  (18.335765, -64.896335)
# 51851     NaN    NaN                          Other  (18.335765, -64.896335)
#
#        LocationID StratificationCategory1                Stratification1
# 48772          59                   Total                          Total
# 48773          59                  Gender                           Male
# 48774          59                  Gender                         Female
# 48775          59               Education          Less than high school
# 48776          59               Education           High school graduate
# ...           ...                     ...                            ...
# 51847          78          Race/Ethnicity                          Asian
# 51848          78          Race/Ethnicity      Hawaiian/Pacific Islander
# 51849          78          Race/Ethnicity  American Indian/Alaska Native
# 51850          78          Race/Ethnicity                2 or more races
# 51851          78          Race/Ethnicity                          Other
#
# [3080 rows x 17 columns]

# %% [markdown]
# # (2016) New Gender, Income, Age Data Frames

# %% [markdown]
# ### Create Gender Data Frame (2016)

# %%
# Gender Dataset 2016
# create filter that only looks at gender rows 
obesity_in_US_gender_2016=obesity_in_US_df4[(obesity_in_US_df4['Stratification1']=='Male')|(obesity_in_US_df4['Stratification1']=='Female')]
obesity_in_US_gender_2016 = obesity_in_US_gender_2016.drop(['Age(years)','Education','Income','Race/Ethnicity'],1);

# %%
obesity_in_US_gender_2016.columns
cols_to_use = ['YearStart', 'LocationAbbr', 'LocationDesc', 'Data_Value', 'Data_Value_Alt', 'Question', 'Sample_Size', 'Total', 'Gender', 'GeoLocation', 'LocationID', 'StratificationCategory1', 'Stratification1']
obesity_in_US_gender_2016=obesity_in_US_gender_2016[cols_to_use]

obesity_in_US_gender_2016_labels = {
    'YearStart': 'year',
    'LocationAbbr': 'state',
    'LocationDesc': 'state_name',
    'Data_Value': 'gender_pc',
    'Data_Value_Alt': 'Data_Value_Alt',
    'Question': 'Question',
    'Sample_Size': 'Sample_Size', 
    'Total' : 'Total',
    'Gender': 'Gender', 
    'GeoLocation': 'GeoLocation', 
    'LocationID': 'LocationID', 
    'StratificationCategory1': 'StratificationCategory1', 
    'Stratification1': 'Stratification1'
}
obesity_in_US_gender_2016 = obesity_in_US_gender_2016.rename(columns = obesity_in_US_gender_2016_labels)

# %%
obesity_in_US_gender_2016 = obesity_in_US_gender_2016.reset_index(drop = True)
obesity_in_US_gender_2016
# Out:
#      year state      state_name  gender_pc  Data_Value_Alt  \
# 0    2016    US        National       41.0            41.0
# 1    2016    US        National       29.3            29.3
# 2    2016    AR        Arkansas       38.0            38.0
# 3    2016    AR        Arkansas       27.0            27.0
# 4    2016    AL         Alabama       38.2            38.2
# ..    ...   ...             ...        ...             ...
# 215  2016    GU            Guam       27.3            27.3
# 216  2016    PR     Puerto Rico       30.0            30.0
# 217  2016    PR     Puerto Rico       31.4            31.4
# 218  2016    VI  Virgin Islands       22.2            22.2
# 219  2016    VI  Virgin Islands       41.9            41.9
#
#                                               Question  Sample_Size Total  \
# 0    Percent of adults aged 18 years and older who ...     198440.0   NaN
# 1    Percent of adults aged 18 years and older who ...     240000.0   NaN
# 2    Percent of adults aged 18 years and older who ...       1918.0   NaN
# 3    Percent of adults aged 18 years and older who ...       2941.0   NaN
# 4    Percent of adults aged 18 years and older who ...       2711.0   NaN
# ..                                                 ...          ...   ...
# 215  Percent of adults aged 18 years and older who ...        805.0   NaN
# 216  Percent of adults aged 18 years and older who ...       2105.0   NaN
# 217  Percent of adults aged 18 years and older who ...       3423.0   NaN
# 218  Percent of adults aged 18 years and older who ...        468.0   NaN
# 219  Percent of adults aged 18 years and older who ...        735.0   NaN
#
#      Gender                              GeoLocation  LocationID  \
# 0      Male                                      NaN          59
# 1    Female                                      NaN          59
# 2      Male  (34.74865012400045, -92.27449074299966)           5
# 3    Female  (34.74865012400045, -92.27449074299966)           5
# 4      Male  (32.84057112200048, -86.63186076199969)           1
# ..      ...                                      ...         ...
# 215  Female                  (13.444304, 144.793731)          66
# 216    Male                  (18.220833, -66.590149)          72
# 217  Female                  (18.220833, -66.590149)          72
# 218    Male                  (18.335765, -64.896335)          78
# 219  Female                  (18.335765, -64.896335)          78
#
#     StratificationCategory1 Stratification1
# 0                    Gender            Male
# 1                    Gender          Female
# 2                    Gender            Male
# 3                    Gender          Female
# 4                    Gender            Male
# ..                      ...             ...
# 215                  Gender          Female
# 216                  Gender            Male
# 217                  Gender          Female
# 218                  Gender            Male
# 219                  Gender          Female
#
# [220 rows x 13 columns]

# %%
# Saving gender dataframe "obesity_in_US_gender_2016.csv"
obesity_in_US_gender_2016.to_csv('../data/Clean Data/obesity_in_US_gender_2016.csv')

# %% [markdown]
# ### Create Income Data Frame (2016)

# %%
# Income Dataset (2016)
# create filter that only looks at income rows 
obesity_in_US_income_2016=obesity_in_US_df4[obesity_in_US_df4['StratificationCategory1']=='Income']
obesity_in_US_income_2016 = obesity_in_US_income_2016.drop(['Age(years)','Gender','Education','Race/Ethnicity'],1);

# %%
obesity_in_US_income_2016.columns
cols_to_use = ['YearStart', 'LocationAbbr', 'LocationDesc', 'Data_Value', 'Data_Value_Alt', 'Question', 'Sample_Size', 'Total', 'Income', 'GeoLocation', 'LocationID', 'StratificationCategory1', 'Stratification1']
obesity_in_US_income_2016=obesity_in_US_income_2016[cols_to_use]

obesity_in_US_income_2016_labels = {
    'YearStart': 'year',
    'LocationAbbr': 'state',
    'LocationDesc': 'state_name',
    'Data_Value': 'income_pc',
    'Data_Value_Alt': 'Data_Value_Alt',
    'Question': 'Question',
    'Sample_Size': 'Sample_Size', 
    'Total' : 'Total',
    'Income': 'Income', 
    'GeoLocation': 'GeoLocation', 
    'LocationID': 'LocationID', 
    'StratificationCategory1': 'StratificationCategory1', 
    'Stratification1': 'Stratification1'
}
obesity_in_US_income_2016 = obesity_in_US_income_2016.rename(columns = obesity_in_US_income_2016_labels)

# %%
obesity_in_US_income_2016 = obesity_in_US_income_2016.reset_index(drop = True)
obesity_in_US_income_2016
# Out:
#      year state      state_name  income_pc  Data_Value_Alt  \
# 0    2016    AZ         Arizona       34.7            34.7
# 1    2016    AZ         Arizona       30.9            30.9
# 2    2016    AZ         Arizona       34.1            34.1
# 3    2016    AZ         Arizona       35.3            35.3
# 4    2016    AZ         Arizona       36.5            36.5
# ..    ...   ...             ...        ...             ...
# 765  2016    VI  Virgin Islands       30.6            30.6
# 766  2016    VI  Virgin Islands       36.3            36.3
# 767  2016    VI  Virgin Islands       43.3            43.3
# 768  2016    VI  Virgin Islands       32.6            32.6
# 769  2016    VI  Virgin Islands       31.8            31.8
#
#                                               Question  Sample_Size Total  \
# 0    Percent of adults aged 18 years and older who ...        842.0   NaN
# 1    Percent of adults aged 18 years and older who ...       1379.0   NaN
# 2    Percent of adults aged 18 years and older who ...        918.0   NaN
# 3    Percent of adults aged 18 years and older who ...       1355.0   NaN
# 4    Percent of adults aged 18 years and older who ...       1421.0   NaN
# ..                                                 ...          ...   ...
# 765  Percent of adults aged 18 years and older who ...        150.0   NaN
# 766  Percent of adults aged 18 years and older who ...        153.0   NaN
# 767  Percent of adults aged 18 years and older who ...        158.0   NaN
# 768  Percent of adults aged 18 years and older who ...        206.0   NaN
# 769  Percent of adults aged 18 years and older who ...        106.0   NaN
#
#                  Income                                GeoLocation  \
# 0     Less than $15,000  (34.865970280000454, -111.76381127699972)
# 1     $15,000 - $24,999  (34.865970280000454, -111.76381127699972)
# 2     $25,000 - $34,999  (34.865970280000454, -111.76381127699972)
# 3     $35,000 - $49,999  (34.865970280000454, -111.76381127699972)
# 4     $50,000 - $74,999  (34.865970280000454, -111.76381127699972)
# ..                  ...                                        ...
# 765   $25,000 - $34,999                    (18.335765, -64.896335)
# 766   $35,000 - $49,999                    (18.335765, -64.896335)
# 767   $50,000 - $74,999                    (18.335765, -64.896335)
# 768  $75,000 or greater                    (18.335765, -64.896335)
# 769   Data not reported                    (18.335765, -64.896335)
#
#      LocationID StratificationCategory1     Stratification1
# 0             4                  Income   Less than $15,000
# 1             4                  Income   $15,000 - $24,999
# 2             4                  Income   $25,000 - $34,999
# 3             4                  Income   $35,000 - $49,999
# 4             4                  Income   $50,000 - $74,999
# ..          ...                     ...                 ...
# 765          78                  Income   $25,000 - $34,999
# 766          78                  Income   $35,000 - $49,999
# 767          78                  Income   $50,000 - $74,999
# 768          78                  Income  $75,000 or greater
# 769          78                  Income   Data not reported
#
# [770 rows x 13 columns]

# %%
obesity_in_US_income_2016.to_csv('../data/Clean Data/obesity_in_US_income_2016.csv')

# %% [markdown]
# ### Create Age Data Frame (2016)

# %%
# Age Dataset (2016)
# create filter that only looks at income rows 
obesity_in_US_age_2016=obesity_in_US_df4[(obesity_in_US_df4['Stratification1']=='18 - 24')|(obesity_in_US_df4['Stratification1']=='35 - 44')|(obesity_in_US_df4['Stratification1']=='45 - 54')|(obesity_in_US_df4['Stratification1']=='55 - 64')|(obesity_in_US_df4['Stratification1']=='65 or older')]
obesity_in_US_age_2016 = obesity_in_US_age_2016.drop(['Income','Gender','Education','Race/Ethnicity'],1);

# %%
obesity_in_US_age_2016.columns
cols_to_use = ['YearStart', 'LocationAbbr', 'LocationDesc', 'Data_Value', 'Data_Value_Alt', 'Question', 'Sample_Size', 'Total', 'Age(years)', 'GeoLocation', 'LocationID', 'StratificationCategory1', 'Stratification1']
obesity_in_US_age_2016=obesity_in_US_age_2016[cols_to_use]

obesity_in_US_age_2016_labels = {
    'YearStart': 'year',
    'LocationAbbr': 'state',
    'LocationDesc': 'state_name',
    'Data_Value': 'age_pc',
    'Data_Value_Alt': 'Data_Value_Alt',
    'Question': 'Question',
    'Sample_Size': 'Sample_Size', 
    'Total' : 'Total',
    'Age(years)': 'Age', 
    'GeoLocation': 'GeoLocation', 
    'LocationID': 'LocationID', 
    'StratificationCategory1': 'StratificationCategory1', 
    'Stratification1': 'Stratification1'
}
obesity_in_US_age_2016 = obesity_in_US_age_2016.rename(columns = obesity_in_US_age_2016_labels)

# %%
obesity_in_US_age_2016 = obesity_in_US_age_2016.reset_index(drop = True)
obesity_in_US_age_2016
# Out:
#      year state      state_name  age_pc  Data_Value_Alt  \
# 0    2016    US        National    25.5            25.5
# 1    2016    US        National    35.7            35.7
# 2    2016    AZ         Arizona    37.6            37.6
# 3    2016    AZ         Arizona    39.1            39.1
# 4    2016    AZ         Arizona    38.6            38.6
# ..    ...   ...             ...     ...             ...
# 545  2016    VI  Virgin Islands    15.5            15.5
# 546  2016    VI  Virgin Islands    39.8            39.8
# 547  2016    VI  Virgin Islands    41.4            41.4
# 548  2016    VI  Virgin Islands    33.2            33.2
# 549  2016    VI  Virgin Islands    19.3            19.3
#
#                                               Question  Sample_Size Total  \
# 0    Percent of adults aged 18 years and older who ...      23734.0   NaN
# 1    Percent of adults aged 18 years and older who ...      48951.0   NaN
# 2    Percent of adults aged 18 years and older who ...       1281.0   NaN
# 3    Percent of adults aged 18 years and older who ...       2127.0   NaN
# 4    Percent of adults aged 18 years and older who ...       4790.0   NaN
# ..                                                 ...          ...   ...
# 545  Percent of adults aged 18 years and older who ...         50.0   NaN
# 546  Percent of adults aged 18 years and older who ...         91.0   NaN
# 547  Percent of adults aged 18 years and older who ...        217.0   NaN
# 548  Percent of adults aged 18 years and older who ...        306.0   NaN
# 549  Percent of adults aged 18 years and older who ...        436.0   NaN
#
#              Age                                GeoLocation  LocationID  \
# 0        18 - 24                                        NaN          59
# 1        35 - 44                                        NaN          59
# 2        45 - 54  (34.865970280000454, -111.76381127699972)           4
# 3        55 - 64  (34.865970280000454, -111.76381127699972)           4
# 4    65 or older  (34.865970280000454, -111.76381127699972)           4
# ..           ...                                        ...         ...
# 545      18 - 24                    (18.335765, -64.896335)          78
# 546      35 - 44                    (18.335765, -64.896335)          78
# 547      45 - 54                    (18.335765, -64.896335)          78
# 548      55 - 64                    (18.335765, -64.896335)          78
# 549  65 or older                    (18.335765, -64.896335)          78
#
#     StratificationCategory1 Stratification1
# 0               Age (years)         18 - 24
# 1               Age (years)         35 - 44
# 2               Age (years)         45 - 54
# 3               Age (years)         55 - 64
# 4               Age (years)     65 or older
# ..                      ...             ...
# 545             Age (years)         18 - 24
# 546             Age (years)         35 - 44
# 547             Age (years)         45 - 54
# 548             Age (years)         55 - 64
# 549             Age (years)     65 or older
#
# [550 rows x 13 columns]

# %%
# Saving age dataset 'obesity_in_US_age_2016.csv'
obesity_in_US_age_2016.to_csv('../data/Clean Data/obesity_in_US_age_2016.csv')
