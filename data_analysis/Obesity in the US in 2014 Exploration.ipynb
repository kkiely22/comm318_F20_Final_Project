# %% [markdown]
# # Obesity in the US in 2014 Exploration
# - This is a dataset that looks at adults 18 years and older across the United States who are obese.
# - This data differentiates people by age, income, education, gender, and race/ethnicity.
# - In this notebook, I will explore and clean the dataset and create new data frames for deeper analysis
#     - I will clean up the columns and filter out the year column to only look at 2014 for age, income, and gender.
#     - I will make data frames for gender obesity rates in 2014, age obesity rates in 2014, and income obesity rates in 2014

# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as np
import sys
import matplotlib 
import seaborn as sns
import numpy as np


# %matplotlib inline

# %% [markdown]
# # Load & Inspect Data

# %%
obesity_in_US_df = pd.read_csv('../data/Raw Data/Nutrition_Physical_Activity_and_Obesity_Behavioral_Risk_Factor_Surveillance_System.csv')
obesity_in_US_df.shape
# Out:
# (53392, 33)

# %%
obesity_in_US_df.sample(20)
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 24157       2013     2013           ND    North Dakota
# 27845       2011     2011           SC  South Carolina
# 49669       2016     2016           NH   New Hampshire
# 42398       2015     2015           NH   New Hampshire
# 6357        2012     2012           FL         Florida
# 32155       2013     2013           VA        Virginia
# 17284       2013     2013           MO        Missouri
# 39723       2015     2015           GA         Georgia
# 2523        2013     2013           AR        Arkansas
# 43890       2015     2015           SC  South Carolina
# 46540       2015     2015           IN         Indiana
# 9203        2013     2013           IL        Illinois
# 9473        2014     2014           IL        Illinois
# 7468        2014     2014           GU            Guam
# 45298       2015     2015           WY         Wyoming
# 50403       2016     2016           AL         Alabama
# 3817        2013     2013           CO        Colorado
# 52006       2016     2016           AZ         Arizona
# 45563       2015     2015           GU            Guam
# 9762        2012     2012           IN         Indiana
#
#                                        Datasource                    Class  \
# 24157  Behavioral Risk Factor Surveillance System        Physical Activity
# 27845  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 49669  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 42398  Behavioral Risk Factor Surveillance System        Physical Activity
# 6357   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 32155  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 17284  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 39723  Behavioral Risk Factor Surveillance System        Physical Activity
# 2523   Behavioral Risk Factor Surveillance System        Physical Activity
# 43890  Behavioral Risk Factor Surveillance System        Physical Activity
# 46540  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 9203   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 9473   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 7468   Behavioral Risk Factor Surveillance System        Physical Activity
# 45298  Behavioral Risk Factor Surveillance System        Physical Activity
# 50403  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3817   Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 52006  Behavioral Risk Factor Surveillance System        Physical Activity
# 45563  Behavioral Risk Factor Surveillance System        Physical Activity
# 9762   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                                   Topic  \
# 24157      Physical Activity - Behavior
# 27845  Fruits and Vegetables - Behavior
# 49669           Obesity / Weight Status
# 42398      Physical Activity - Behavior
# 6357            Obesity / Weight Status
# 32155           Obesity / Weight Status
# 17284           Obesity / Weight Status
# 39723      Physical Activity - Behavior
# 2523       Physical Activity - Behavior
# 43890      Physical Activity - Behavior
# 46540           Obesity / Weight Status
# 9203            Obesity / Weight Status
# 9473            Obesity / Weight Status
# 7468       Physical Activity - Behavior
# 45298      Physical Activity - Behavior
# 50403           Obesity / Weight Status
# 3817   Fruits and Vegetables - Behavior
# 52006      Physical Activity - Behavior
# 45563      Physical Activity - Behavior
# 9762            Obesity / Weight Status
#
#                                                 Question  Data_Value_Unit  \
# 24157  Percent of adults who engage in muscle-strengt...              NaN
# 27845  Percent of adults who report consuming fruit l...              NaN
# 49669  Percent of adults aged 18 years and older who ...              NaN
# 42398  Percent of adults who engage in no leisure-tim...              NaN
# 6357   Percent of adults aged 18 years and older who ...              NaN
# 32155  Percent of adults aged 18 years and older who ...              NaN
# 17284  Percent of adults aged 18 years and older who ...              NaN
# 39723  Percent of adults who engage in no leisure-tim...              NaN
# 2523   Percent of adults who achieve at least 150 min...              NaN
# 43890  Percent of adults who achieve at least 300 min...              NaN
# 46540  Percent of adults aged 18 years and older who ...              NaN
# 9203   Percent of adults aged 18 years and older who ...              NaN
# 9473   Percent of adults aged 18 years and older who ...              NaN
# 7468   Percent of adults who engage in no leisure-tim...              NaN
# 45298  Percent of adults who achieve at least 300 min...              NaN
# 50403  Percent of adults aged 18 years and older who ...              NaN
# 3817   Percent of adults who report consuming vegetab...              NaN
# 52006  Percent of adults who engage in no leisure-tim...              NaN
# 45563  Percent of adults who achieve at least 300 min...              NaN
# 9762   Percent of adults aged 18 years and older who ...              NaN
#
#       Data_Value_Type  ...                                GeoLocation  \
# 24157           Value  ...   (47.47531977900047, -100.11842104899966)
# 27845           Value  ...   (33.998821303000454, -81.04537120699968)
# 49669           Value  ...    (43.65595011300047, -71.50036091999965)
# 42398           Value  ...    (43.65595011300047, -71.50036091999965)
# 6357            Value  ...   (28.932040377000476, -81.92896053899966)
# 32155           Value  ...    (37.54268067400045, -78.45789046299967)
# 17284           Value  ...   (38.635790776000476, -92.56630005299968)
# 39723           Value  ...    (32.83968109300048, -83.62758034599966)
# 2523            Value  ...    (34.74865012400045, -92.27449074299966)
# 43890           Value  ...   (33.998821303000454, -81.04537120699968)
# 46540           Value  ...   (39.766910452000445, -86.14996019399968)
# 9203            Value  ...    (40.48501028300046, -88.99771017799969)
# 9473            Value  ...    (40.48501028300046, -88.99771017799969)
# 7468            Value  ...                    (13.444304, 144.793731)
# 45298           Value  ...   (43.23554134300048, -108.10983035299967)
# 50403           Value  ...    (32.84057112200048, -86.63186076199969)
# 3817            Value  ...  (38.843840757000464, -106.13361092099967)
# 52006           Value  ...  (34.865970280000454, -111.76381127699972)
# 45563           Value  ...                    (13.444304, 144.793731)
# 9762            Value  ...   (39.766910452000445, -86.14996019399968)
#
#        ClassID TopicID QuestionID  DataValueTypeID  LocationID  \
# 24157       PA     PA1       Q046            VALUE          38
# 27845       FV     FV1       Q018            VALUE          45
# 49669      OWS    OWS1       Q037            VALUE          33
# 42398       PA     PA1       Q047            VALUE          33
# 6357       OWS    OWS1       Q037            VALUE          12
# 32155      OWS    OWS1       Q036            VALUE          51
# 17284      OWS    OWS1       Q037            VALUE          29
# 39723       PA     PA1       Q047            VALUE          13
# 2523        PA     PA1       Q044            VALUE           5
# 43890       PA     PA1       Q045            VALUE          45
# 46540      OWS    OWS1       Q036            VALUE          18
# 9203       OWS    OWS1       Q037            VALUE          17
# 9473       OWS    OWS1       Q037            VALUE          17
# 7468        PA     PA1       Q047            VALUE          66
# 45298       PA     PA1       Q045            VALUE          56
# 50403      OWS    OWS1       Q036            VALUE           1
# 3817        FV     FV1       Q019            VALUE           8
# 52006       PA     PA1       Q047            VALUE           4
# 45563       PA     PA1       Q045            VALUE          66
# 9762       OWS    OWS1       Q036            VALUE          18
#
#        StratificationCategory1                Stratification1  \
# 24157              Age (years)                        25 - 34
# 27845           Race/Ethnicity                2 or more races
# 49669           Race/Ethnicity  American Indian/Alaska Native
# 42398                   Income              $25,000 - $34,999
# 6357                    Income              $15,000 - $24,999
# 32155              Age (years)                        18 - 24
# 17284           Race/Ethnicity                2 or more races
# 39723              Age (years)                        55 - 64
# 2523                    Income              Data not reported
# 43890           Race/Ethnicity      Hawaiian/Pacific Islander
# 46540              Age (years)                        45 - 54
# 9203               Age (years)                        45 - 54
# 9473            Race/Ethnicity                2 or more races
# 7468               Age (years)                        55 - 64
# 45298           Race/Ethnicity                       Hispanic
# 50403              Age (years)                        45 - 54
# 3817                    Income              $35,000 - $49,999
# 52006                   Income              Data not reported
# 45563                   Income              $50,000 - $74,999
# 9762                 Education               College graduate
#
#       StratificationCategoryId1 StratificationID1
# 24157                     AGEYR         AGEYR2534
# 27845                      RACE         RACE2PLUS
# 49669                      RACE           RACENAA
# 42398                       INC           INC2535
# 6357                        INC           INC1525
# 32155                     AGEYR         AGEYR1824
# 17284                      RACE         RACE2PLUS
# 39723                     AGEYR         AGEYR5564
# 2523                        INC             INCNR
# 43890                      RACE           RACEHPI
# 46540                     AGEYR         AGEYR4554
# 9203                      AGEYR         AGEYR4554
# 9473                       RACE         RACE2PLUS
# 7468                      AGEYR         AGEYR5564
# 45298                      RACE           RACEHIS
# 50403                     AGEYR         AGEYR4554
# 3817                        INC           INC3550
# 52006                       INC             INCNR
# 45563                       INC           INC5075
# 9762                        EDU         EDUCOGRAD
#
# [20 rows x 33 columns]

# %% [markdown]
# # Make a 2014 data frame

# %%
# dropping unnecessary columns
# rename Stratication1 and StratificationCategory1 and grouping age, education, income, gender, race/ethnicity into columns

obesity_in_US_cols = obesity_in_US_df.drop(['Low_Confidence_Limit','High_Confidence_Limit ','YearEnd','Topic','Class','Datasource','Data_Value_Unit','QuestionID','ClassID','TopicID','DataValueTypeID','Data_Value_Type','Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategoryId1','StratificationID1'],1);

#Focusing only on 2014
#create filter 'obesity_in_US_cols' in order to not use certain columns 
obesity_in_US_year2014=obesity_in_US_cols[obesity_in_US_cols['YearStart']==2014]
obesity_in_US_year2014
# Out:
#        YearStart LocationAbbr LocationDesc  \
# 299         2014           AL      Alabama
# 354         2014           AL      Alabama
# 428         2014           AL      Alabama
# 469         2014           US     National
# 599         2014           AL      Alabama
# ...          ...          ...          ...
# 35168       2014           WY      Wyoming
# 35169       2014           WY      Wyoming
# 35170       2014           WY      Wyoming
# 35171       2014           WY      Wyoming
# 35172       2014           WY      Wyoming
#
#                                                 Question  Data_Value  \
# 299    Percent of adults aged 18 years and older who ...        32.9
# 354    Percent of adults aged 18 years and older who ...        35.1
# 428    Percent of adults who engage in no leisure-tim...        24.2
# 469    Percent of adults who engage in no leisure-tim...        21.7
# 599    Percent of adults aged 18 years and older who ...        33.5
# ...                                                  ...         ...
# 35168  Percent of adults who engage in no leisure-tim...         NaN
# 35169  Percent of adults who engage in no leisure-tim...         NaN
# 35170  Percent of adults who engage in no leisure-tim...        39.8
# 35171  Percent of adults who engage in no leisure-tim...        17.1
# 35172  Percent of adults who engage in no leisure-tim...        32.5
#
#        Data_Value_Alt  Sample_Size  Total Age(years) Education  Gender Income  \
# 299              32.9       5156.0    NaN        NaN       NaN  Female    NaN
# 354              35.1       1886.0    NaN    55 - 64       NaN     NaN    NaN
# 428              24.2       3109.0    NaN        NaN       NaN    Male    NaN
# 469              21.7     188835.0    NaN        NaN       NaN    Male    NaN
# 599              33.5       8190.0  Total        NaN       NaN     NaN    NaN
# ...               ...          ...    ...        ...       ...     ...    ...
# 35168             NaN          NaN    NaN        NaN       NaN     NaN    NaN
# 35169             NaN          NaN    NaN        NaN       NaN     NaN    NaN
# 35170            39.8         76.0    NaN        NaN       NaN     NaN    NaN
# 35171            17.1         72.0    NaN        NaN       NaN     NaN    NaN
# 35172            32.5         63.0    NaN        NaN       NaN     NaN    NaN
#
#                       Race/Ethnicity  \
# 299                              NaN
# 354                              NaN
# 428                              NaN
# 469                              NaN
# 599                              NaN
# ...                              ...
# 35168                          Asian
# 35169      Hawaiian/Pacific Islander
# 35170  American Indian/Alaska Native
# 35171                2 or more races
# 35172                          Other
#
#                                     GeoLocation  LocationID  \
# 299     (32.84057112200048, -86.63186076199969)           1
# 354     (32.84057112200048, -86.63186076199969)           1
# 428     (32.84057112200048, -86.63186076199969)           1
# 469                                         NaN          59
# 599     (32.84057112200048, -86.63186076199969)           1
# ...                                         ...         ...
# 35168  (43.23554134300048, -108.10983035299967)          56
# 35169  (43.23554134300048, -108.10983035299967)          56
# 35170  (43.23554134300048, -108.10983035299967)          56
# 35171  (43.23554134300048, -108.10983035299967)          56
# 35172  (43.23554134300048, -108.10983035299967)          56
#
#       StratificationCategory1                Stratification1
# 299                    Gender                         Female
# 354               Age (years)                        55 - 64
# 428                    Gender                           Male
# 469                    Gender                           Male
# 599                     Total                          Total
# ...                       ...                            ...
# 35168          Race/Ethnicity                          Asian
# 35169          Race/Ethnicity      Hawaiian/Pacific Islander
# 35170          Race/Ethnicity  American Indian/Alaska Native
# 35171          Race/Ethnicity                2 or more races
# 35172          Race/Ethnicity                          Other
#
# [4536 rows x 17 columns]

# %%
# Explore the questions in order to create a filter that only uses 
       #q1: 'Percent of adults aged 18 years and older who have obesity',
       #q2: 'Percent of adults aged 18 years and older who have an overweight classification'
obesity_in_US_year2014['Question'].unique()
# Out:
# array(['Percent of adults aged 18 years and older who have obesity',
#        'Percent of adults aged 18 years and older who have an overweight classification',
#        'Percent of adults who engage in no leisure-time physical activity'],
#       dtype=object)

# %%
# create filter that chooses the following questions: 
# filter uses obesity_in_US_year2014 because we are only looking at 2014
       #q1: 'Percent of adults aged 18 years and older who have obesity',
       #q2: 'Percent of adults aged 18 years and older who have an overweight classification'
questions_filter=obesity_in_US_year2014[(obesity_in_US_year2014['Question']=='Percent of adults aged 18 years and older who have obesity') | (obesity_in_US_year2014['Question']=='Percent of adults aged 18 years and older who have an overweight classification')]
questions_filter['Question'].unique()
# Out:
# array(['Percent of adults aged 18 years and older who have obesity',
#        'Percent of adults aged 18 years and older who have an overweight classification'],
#       dtype=object)

# %%
# Rename "questions_filter" to "obesity_in_US_df2"
obesity_in_US_df2 = questions_filter
obesity_in_US_df2
# Out:
#        YearStart LocationAbbr LocationDesc  \
# 299         2014           AL      Alabama
# 354         2014           AL      Alabama
# 599         2014           AL      Alabama
# 600         2014           AL      Alabama
# 601         2014           AL      Alabama
# ...          ...          ...          ...
# 35141       2014           WY      Wyoming
# 35142       2014           WY      Wyoming
# 35143       2014           WY      Wyoming
# 35144       2014           WY      Wyoming
# 35145       2014           WY      Wyoming
#
#                                                 Question  Data_Value  \
# 299    Percent of adults aged 18 years and older who ...        32.9
# 354    Percent of adults aged 18 years and older who ...        35.1
# 599    Percent of adults aged 18 years and older who ...        33.5
# 600    Percent of adults aged 18 years and older who ...        34.1
# 601    Percent of adults aged 18 years and older who ...        34.8
# ...                                                  ...         ...
# 35141  Percent of adults aged 18 years and older who ...         NaN
# 35142  Percent of adults aged 18 years and older who ...         NaN
# 35143  Percent of adults aged 18 years and older who ...        30.0
# 35144  Percent of adults aged 18 years and older who ...        33.2
# 35145  Percent of adults aged 18 years and older who ...        48.9
#
#        Data_Value_Alt  Sample_Size  Total Age(years)              Education  \
# 299              32.9       5156.0    NaN        NaN                    NaN
# 354              35.1       1886.0    NaN    55 - 64                    NaN
# 599              33.5       8190.0  Total        NaN                    NaN
# 600              34.1       3034.0    NaN        NaN                    NaN
# 601              34.8        995.0    NaN        NaN  Less than high school
# ...               ...          ...    ...        ...                    ...
# 35141             NaN          NaN    NaN        NaN                    NaN
# 35142             NaN          NaN    NaN        NaN                    NaN
# 35143            30.0         72.0    NaN        NaN                    NaN
# 35144            33.2         70.0    NaN        NaN                    NaN
# 35145            48.9         58.0    NaN        NaN                    NaN
#
#        Gender Income                 Race/Ethnicity  \
# 299    Female    NaN                            NaN
# 354       NaN    NaN                            NaN
# 599       NaN    NaN                            NaN
# 600      Male    NaN                            NaN
# 601       NaN    NaN                            NaN
# ...       ...    ...                            ...
# 35141     NaN    NaN                          Asian
# 35142     NaN    NaN      Hawaiian/Pacific Islander
# 35143     NaN    NaN  American Indian/Alaska Native
# 35144     NaN    NaN                2 or more races
# 35145     NaN    NaN                          Other
#
#                                     GeoLocation  LocationID  \
# 299     (32.84057112200048, -86.63186076199969)           1
# 354     (32.84057112200048, -86.63186076199969)           1
# 599     (32.84057112200048, -86.63186076199969)           1
# 600     (32.84057112200048, -86.63186076199969)           1
# 601     (32.84057112200048, -86.63186076199969)           1
# ...                                         ...         ...
# 35141  (43.23554134300048, -108.10983035299967)          56
# 35142  (43.23554134300048, -108.10983035299967)          56
# 35143  (43.23554134300048, -108.10983035299967)          56
# 35144  (43.23554134300048, -108.10983035299967)          56
# 35145  (43.23554134300048, -108.10983035299967)          56
#
#       StratificationCategory1                Stratification1
# 299                    Gender                         Female
# 354               Age (years)                        55 - 64
# 599                     Total                          Total
# 600                    Gender                           Male
# 601                 Education          Less than high school
# ...                       ...                            ...
# 35141          Race/Ethnicity                          Asian
# 35142          Race/Ethnicity      Hawaiian/Pacific Islander
# 35143          Race/Ethnicity  American Indian/Alaska Native
# 35144          Race/Ethnicity                2 or more races
# 35145          Race/Ethnicity                          Other
#
# [3024 rows x 17 columns]

# %%
# Saving dataset "obesity_in_US_df2" with year2014 and obesity/overweight questions
obesity_in_US_df2.to_csv('../data/Clean Data/Obesity_in_US_2014cleaned.csv')

# %% [markdown]
# # (2014) New Gender, Income, Age Data Frames

# %% [markdown]
# ### Create Gender Data Frame (2014)

# %%
# Gender Dataset 2014
# create filter that only looks at gender rows 
#rename columns
obesity_in_US_gender_2014=obesity_in_US_df2[(obesity_in_US_df2['Stratification1']=='Male')|(obesity_in_US_df2['Stratification1']=='Female')]
obesity_in_US_gender_2014 = obesity_in_US_gender_2014.drop(['Age(years)','Education','Income','Race/Ethnicity'],1);

# %%
obesity_in_US_gender_2014.columns
cols_to_use = ['YearStart', 'LocationAbbr', 'LocationDesc', 'Data_Value', 'Data_Value_Alt', 'Question', 'Sample_Size', 'Total', 'Gender', 'GeoLocation', 'LocationID', 'StratificationCategory1', 'Stratification1']
obesity_in_US_gender_2014=obesity_in_US_gender_2014[cols_to_use]

obesity_in_US_gender_2014_labels = {
    'YearStart': 'year',
    'LocationAbbr': 'state',
    'LocationDesc': 'state_name',
    'Data_Value': 'gender_pc',
    'Data_Value_Alt': 'Data_Value_Alt',
    'Question': 'Question',
    'Sample_Size': 'Sample_Size', 
    'Total' : 'Total',
    'Gender': 'Gender', 
    'GeoLocation': 'GeoLocation', 
    'LocationID': 'LocationID', 
    'StratificationCategory1': 'StratificationCategory1', 
    'Stratification1': 'Stratification1'
}
obesity_in_US_gender_2014 = obesity_in_US_gender_2014.rename(columns = obesity_in_US_gender_2014_labels)

# %%
obesity_in_US_gender_2014 = obesity_in_US_gender_2014.reset_index(drop = True)
obesity_in_US_gender_2014
# Out:
#      year state state_name  gender_pc  Data_Value_Alt  \
# 0    2014    AL    Alabama       32.9            32.9
# 1    2014    AL    Alabama       34.1            34.1
# 2    2014    AL    Alabama       37.2            37.2
# 3    2014    AL    Alabama       29.8            29.8
# 4    2014    AK     Alaska       29.3            29.3
# ..    ...   ...        ...        ...             ...
# 211  2014    WI  Wisconsin       29.6            29.6
# 212  2014    WY    Wyoming       29.7            29.7
# 213  2014    WY    Wyoming       29.2            29.2
# 214  2014    WY    Wyoming       41.7            41.7
# 215  2014    WY    Wyoming       27.8            27.8
#
#                                               Question  Sample_Size Total  \
# 0    Percent of adults aged 18 years and older who ...       5156.0   NaN
# 1    Percent of adults aged 18 years and older who ...       3034.0   NaN
# 2    Percent of adults aged 18 years and older who ...       3034.0   NaN
# 3    Percent of adults aged 18 years and older who ...       5156.0   NaN
# 4    Percent of adults aged 18 years and older who ...       1921.0   NaN
# ..                                                 ...          ...   ...
# 211  Percent of adults aged 18 years and older who ...       3573.0   NaN
# 212  Percent of adults aged 18 years and older who ...       2490.0   NaN
# 213  Percent of adults aged 18 years and older who ...       3483.0   NaN
# 214  Percent of adults aged 18 years and older who ...       2490.0   NaN
# 215  Percent of adults aged 18 years and older who ...       3483.0   NaN
#
#      Gender                               GeoLocation  LocationID  \
# 0    Female   (32.84057112200048, -86.63186076199969)           1
# 1      Male   (32.84057112200048, -86.63186076199969)           1
# 2      Male   (32.84057112200048, -86.63186076199969)           1
# 3    Female   (32.84057112200048, -86.63186076199969)           1
# 4      Male  (64.84507995700051, -147.72205903599973)           2
# ..      ...                                       ...         ...
# 211  Female   (44.39319117400049, -89.81637074199966)          55
# 212    Male  (43.23554134300048, -108.10983035299967)          56
# 213  Female  (43.23554134300048, -108.10983035299967)          56
# 214    Male  (43.23554134300048, -108.10983035299967)          56
# 215  Female  (43.23554134300048, -108.10983035299967)          56
#
#     StratificationCategory1 Stratification1
# 0                    Gender          Female
# 1                    Gender            Male
# 2                    Gender            Male
# 3                    Gender          Female
# 4                    Gender            Male
# ..                      ...             ...
# 211                  Gender          Female
# 212                  Gender            Male
# 213                  Gender          Female
# 214                  Gender            Male
# 215                  Gender          Female
#
# [216 rows x 13 columns]

# %%
# Saving gender dataframe "obesity_in_US_gender_2014.csv"
obesity_in_US_gender_2014.to_csv('../data/Clean Data/obesity_in_US_gender_2014.csv')

# %% [markdown]
# ### Create Income Data Frame (2014)

# %%
# Income Dataset
# create filter that only looks at income rows 
obesity_in_US_income_2014=obesity_in_US_df2[obesity_in_US_df2['StratificationCategory1']=='Income']
obesity_in_US_income_2014 = obesity_in_US_income_2014.drop(['Age(years)','Gender','Education','Race/Ethnicity'],1);

# %%
obesity_in_US_income_2014.columns
cols_to_use = ['YearStart', 'LocationAbbr', 'LocationDesc', 'Data_Value', 'Data_Value_Alt', 'Question', 'Sample_Size', 'Total', 'Income', 'GeoLocation', 'LocationID', 'StratificationCategory1', 'Stratification1']
obesity_in_US_income_2014=obesity_in_US_income_2014[cols_to_use]

obesity_in_US_income_2014_labels = {
    'YearStart': 'year',
    'LocationAbbr': 'state',
    'LocationDesc': 'state_name',
    'Data_Value': 'income_pc',
    'Data_Value_Alt': 'Data_Value_Alt',
    'Question': 'Question',
    'Sample_Size': 'Sample_Size', 
    'Total' : 'Total',
    'Income': 'Income', 
    'GeoLocation': 'GeoLocation', 
    'LocationID': 'LocationID', 
    'StratificationCategory1': 'StratificationCategory1', 
    'Stratification1': 'Stratification1'
}
obesity_in_US_income_2014 = obesity_in_US_income_2014.rename(columns = obesity_in_US_income_2014_labels)

# %%
obesity_in_US_income_2014 = obesity_in_US_income_2014.reset_index(drop = True)
obesity_in_US_income_2014
# Out:
#      year state state_name  income_pc  Data_Value_Alt  \
# 0    2014    AL    Alabama       34.5            34.5
# 1    2014    AL    Alabama       40.6            40.6
# 2    2014    AL    Alabama       35.4            35.4
# 3    2014    AL    Alabama       35.5            35.5
# 4    2014    AL    Alabama       32.4            32.4
# ..    ...   ...        ...        ...             ...
# 751  2014    WY    Wyoming       31.7            31.7
# 752  2014    WY    Wyoming       32.8            32.8
# 753  2014    WY    Wyoming       39.7            39.7
# 754  2014    WY    Wyoming       38.8            38.8
# 755  2014    WY    Wyoming       33.1            33.1
#
#                                               Question  Sample_Size Total  \
# 0    Percent of adults aged 18 years and older who ...       1108.0   NaN
# 1    Percent of adults aged 18 years and older who ...       1406.0   NaN
# 2    Percent of adults aged 18 years and older who ...        776.0   NaN
# 3    Percent of adults aged 18 years and older who ...        986.0   NaN
# 4    Percent of adults aged 18 years and older who ...        959.0   NaN
# ..                                                 ...          ...   ...
# 751  Percent of adults aged 18 years and older who ...        599.0   NaN
# 752  Percent of adults aged 18 years and older who ...        768.0   NaN
# 753  Percent of adults aged 18 years and older who ...        898.0   NaN
# 754  Percent of adults aged 18 years and older who ...       1498.0   NaN
# 755  Percent of adults aged 18 years and older who ...        965.0   NaN
#
#                  Income                               GeoLocation  LocationID  \
# 0     Less than $15,000   (32.84057112200048, -86.63186076199969)           1
# 1     $15,000 - $24,999   (32.84057112200048, -86.63186076199969)           1
# 2     $25,000 - $34,999   (32.84057112200048, -86.63186076199969)           1
# 3     $35,000 - $49,999   (32.84057112200048, -86.63186076199969)           1
# 4     $50,000 - $74,999   (32.84057112200048, -86.63186076199969)           1
# ..                  ...                                       ...         ...
# 751   $25,000 - $34,999  (43.23554134300048, -108.10983035299967)          56
# 752   $35,000 - $49,999  (43.23554134300048, -108.10983035299967)          56
# 753   $50,000 - $74,999  (43.23554134300048, -108.10983035299967)          56
# 754  $75,000 or greater  (43.23554134300048, -108.10983035299967)          56
# 755   Data not reported  (43.23554134300048, -108.10983035299967)          56
#
#     StratificationCategory1     Stratification1
# 0                    Income   Less than $15,000
# 1                    Income   $15,000 - $24,999
# 2                    Income   $25,000 - $34,999
# 3                    Income   $35,000 - $49,999
# 4                    Income   $50,000 - $74,999
# ..                      ...                 ...
# 751                  Income   $25,000 - $34,999
# 752                  Income   $35,000 - $49,999
# 753                  Income   $50,000 - $74,999
# 754                  Income  $75,000 or greater
# 755                  Income   Data not reported
#
# [756 rows x 13 columns]

# %%
# Saving income dataset 'obesity_in_US_income_2014.csv'
obesity_in_US_income_2014.to_csv('../data/Clean Data/obesity_in_US_income_2014.csv')

# %% [markdown]
# ### Create Age Data Frame (2014)

# %%
# Age Dataset (2014)
# create filter that only looks at income rows 
obesity_in_US_age_2014=obesity_in_US_df2[(obesity_in_US_df2['Stratification1']=='18 - 24')|(obesity_in_US_df2['Stratification1']=='35 - 44')|(obesity_in_US_df2['Stratification1']=='45 - 54')|(obesity_in_US_df2['Stratification1']=='55 - 64')|(obesity_in_US_df2['Stratification1']=='65 or older')]
obesity_in_US_age_2014 = obesity_in_US_age_2014.drop(['Income','Gender','Education','Race/Ethnicity'],1);

# %%
obesity_in_US_age_2014.columns
cols_to_use = ['YearStart', 'LocationAbbr', 'LocationDesc', 'Data_Value', 'Data_Value_Alt', 'Question', 'Sample_Size', 'Total', 'Age(years)', 'GeoLocation', 'LocationID', 'StratificationCategory1', 'Stratification1']
obesity_in_US_age_2014=obesity_in_US_age_2014[cols_to_use]

obesity_in_US_age_2014_labels = {
    'YearStart': 'year',
    'LocationAbbr': 'state',
    'LocationDesc': 'state_name',
    'Data_Value': 'age_pc',
    'Data_Value_Alt': 'Data_Value_Alt',
    'Question': 'Question',
    'Sample_Size': 'Sample_Size', 
    'Total' : 'Total',
    'Age(years)': 'Age', 
    'GeoLocation': 'GeoLocation', 
    'LocationID': 'LocationID', 
    'StratificationCategory1': 'StratificationCategory1', 
    'Stratification1': 'Stratification1'
}
obesity_in_US_age_2014 = obesity_in_US_age_2014.rename(columns = obesity_in_US_age_2014_labels)

# %%
obesity_in_US_age_2014 = obesity_in_US_age_2014.reset_index(drop = True)
obesity_in_US_age_2014
# Out:
#      year state state_name  age_pc  Data_Value_Alt  \
# 0    2014    AL    Alabama    35.1            35.1
# 1    2014    AL    Alabama    20.4            20.4
# 2    2014    AL    Alabama    40.9            40.9
# 3    2014    AL    Alabama    39.9            39.9
# 4    2014    AL    Alabama    37.4            37.4
# ..    ...   ...        ...     ...             ...
# 535  2014    WY    Wyoming    20.3            20.3
# 536  2014    WY    Wyoming    39.0            39.0
# 537  2014    WY    Wyoming    37.1            37.1
# 538  2014    WY    Wyoming    36.8            36.8
# 539  2014    WY    Wyoming    39.9            39.9
#
#                                               Question  Sample_Size Total  \
# 0    Percent of adults aged 18 years and older who ...       1886.0   NaN
# 1    Percent of adults aged 18 years and older who ...        409.0   NaN
# 2    Percent of adults aged 18 years and older who ...        839.0   NaN
# 3    Percent of adults aged 18 years and older who ...       1364.0   NaN
# 4    Percent of adults aged 18 years and older who ...       1886.0   NaN
# ..                                                 ...          ...   ...
# 535  Percent of adults aged 18 years and older who ...        131.0   NaN
# 536  Percent of adults aged 18 years and older who ...        546.0   NaN
# 537  Percent of adults aged 18 years and older who ...        773.0   NaN
# 538  Percent of adults aged 18 years and older who ...       1549.0   NaN
# 539  Percent of adults aged 18 years and older who ...       2621.0   NaN
#
#              Age                               GeoLocation  LocationID  \
# 0        55 - 64   (32.84057112200048, -86.63186076199969)           1
# 1        18 - 24   (32.84057112200048, -86.63186076199969)           1
# 2        35 - 44   (32.84057112200048, -86.63186076199969)           1
# 3        45 - 54   (32.84057112200048, -86.63186076199969)           1
# 4        55 - 64   (32.84057112200048, -86.63186076199969)           1
# ..           ...                                       ...         ...
# 535      18 - 24  (43.23554134300048, -108.10983035299967)          56
# 536      35 - 44  (43.23554134300048, -108.10983035299967)          56
# 537      45 - 54  (43.23554134300048, -108.10983035299967)          56
# 538      55 - 64  (43.23554134300048, -108.10983035299967)          56
# 539  65 or older  (43.23554134300048, -108.10983035299967)          56
#
#     StratificationCategory1 Stratification1
# 0               Age (years)         55 - 64
# 1               Age (years)         18 - 24
# 2               Age (years)         35 - 44
# 3               Age (years)         45 - 54
# 4               Age (years)         55 - 64
# ..                      ...             ...
# 535             Age (years)         18 - 24
# 536             Age (years)         35 - 44
# 537             Age (years)         45 - 54
# 538             Age (years)         55 - 64
# 539             Age (years)     65 or older
#
# [540 rows x 13 columns]

# %%
# Saving age dataset 'obesity_in_US_age_2014.csv'
obesity_in_US_age_2014.to_csv('../data/Clean Data/obesity_in_US_age_2014.csv')
