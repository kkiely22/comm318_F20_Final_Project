# %% [markdown]
# # Obesity in the US Initial Exploration
# - This is a dataset that looks at obesity rates for adults 18 years and older across the United States.
# - This data looks at national obesity rates by age, income, education, gender, and race/ethnicity.
# - In this notebook, I will explore the dataset in order to do deeper analysis in other notebooks

# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy.random as np
import sys
import matplotlib 
import seaborn as sns
import numpy as np


# %matplotlib inline

# %% [markdown]
# # Load & Inspect Data

# %%
obesity_in_US_df = pd.read_csv('../data/Raw Data/Nutrition_Physical_Activity_and_Obesity_Behavioral_Risk_Factor_Surveillance_System.csv')
obesity_in_US_df.shape
# Out:
# (53392, 33)

# %% [markdown]
# There are 53392 rows and 33 columns in this data frame

# %%
obesity_in_US_df.sample(20)
# Out:
#        YearStart  YearEnd LocationAbbr   LocationDesc  \
# 14852       2014     2014           MA  Massachusetts
# 31511       2013     2013           VT        Vermont
# 10800       2014     2014           IA           Iowa
# 33809       2014     2014           WV  West Virginia
# 21606       2011     2011           NM     New Mexico
# 13008       2011     2011           ME          Maine
# 1180        2013     2013           AK         Alaska
# 9761        2012     2012           IN        Indiana
# 7417        2014     2014           GU           Guam
# 45192       2015     2015           WI      Wisconsin
# 2937        2011     2011           CA     California
# 48838       2016     2016           GA        Georgia
# 39044       2015     2015           CO       Colorado
# 50006       2016     2016           TN      Tennessee
# 9924        2013     2013           IN        Indiana
# 35676       2015     2015           FL        Florida
# 23668       2011     2011           ND   North Dakota
# 27344       2011     2011           RI   Rhode Island
# 26937       2014     2014           PR    Puerto Rico
# 47014       2015     2015           MI       Michigan
#
#                                        Datasource                    Class  \
# 14852  Behavioral Risk Factor Surveillance System        Physical Activity
# 31511  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 10800  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 33809  Behavioral Risk Factor Surveillance System        Physical Activity
# 21606  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 13008  Behavioral Risk Factor Surveillance System        Physical Activity
# 1180   Behavioral Risk Factor Surveillance System        Physical Activity
# 9761   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 7417   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 45192  Behavioral Risk Factor Surveillance System        Physical Activity
# 2937   Behavioral Risk Factor Surveillance System        Physical Activity
# 48838  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 39044  Behavioral Risk Factor Surveillance System        Physical Activity
# 50006  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 9924   Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 35676  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 23668  Behavioral Risk Factor Surveillance System    Fruits and Vegetables
# 27344  Behavioral Risk Factor Surveillance System        Physical Activity
# 26937  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 47014  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                                   Topic  \
# 14852      Physical Activity - Behavior
# 31511           Obesity / Weight Status
# 10800           Obesity / Weight Status
# 33809      Physical Activity - Behavior
# 21606           Obesity / Weight Status
# 13008      Physical Activity - Behavior
# 1180       Physical Activity - Behavior
# 9761            Obesity / Weight Status
# 7417            Obesity / Weight Status
# 45192      Physical Activity - Behavior
# 2937       Physical Activity - Behavior
# 48838           Obesity / Weight Status
# 39044      Physical Activity - Behavior
# 50006           Obesity / Weight Status
# 9924   Fruits and Vegetables - Behavior
# 35676  Fruits and Vegetables - Behavior
# 23668  Fruits and Vegetables - Behavior
# 27344      Physical Activity - Behavior
# 26937           Obesity / Weight Status
# 47014           Obesity / Weight Status
#
#                                                 Question  Data_Value_Unit  \
# 14852  Percent of adults who engage in no leisure-tim...              NaN
# 31511  Percent of adults aged 18 years and older who ...              NaN
# 10800  Percent of adults aged 18 years and older who ...              NaN
# 33809  Percent of adults who engage in no leisure-tim...              NaN
# 21606  Percent of adults aged 18 years and older who ...              NaN
# 13008  Percent of adults who achieve at least 150 min...              NaN
# 1180   Percent of adults who achieve at least 150 min...              NaN
# 9761   Percent of adults aged 18 years and older who ...              NaN
# 7417   Percent of adults aged 18 years and older who ...              NaN
# 45192  Percent of adults who engage in no leisure-tim...              NaN
# 2937   Percent of adults who engage in no leisure-tim...              NaN
# 48838  Percent of adults aged 18 years and older who ...              NaN
# 39044  Percent of adults who engage in no leisure-tim...              NaN
# 50006  Percent of adults aged 18 years and older who ...              NaN
# 9924   Percent of adults who report consuming vegetab...              NaN
# 35676  Percent of adults who report consuming fruit l...              NaN
# 23668  Percent of adults who report consuming fruit l...              NaN
# 27344  Percent of adults who engage in no leisure-tim...              NaN
# 26937  Percent of adults aged 18 years and older who ...              NaN
# 47014  Percent of adults aged 18 years and older who ...              NaN
#
#       Data_Value_Type  ...                                GeoLocation  \
# 14852           Value  ...    (42.27687047000046, -72.08269067499964)
# 31511           Value  ...    (43.62538123900049, -72.51764079099962)
# 10800           Value  ...    (42.46940091300047, -93.81649055599968)
# 33809           Value  ...    (38.66551020200046, -80.71264013499967)
# 21606           Value  ...   (34.52088095200048, -106.24058098499967)
# 13008           Value  ...   (45.254228894000505, -68.98503133599962)
# 1180            Value  ...   (64.84507995700051, -147.72205903599973)
# 9761            Value  ...   (39.766910452000445, -86.14996019399968)
# 7417            Value  ...                    (13.444304, 144.793731)
# 45192           Value  ...    (44.39319117400049, -89.81637074199966)
# 2937            Value  ...   (37.63864012300047, -120.99999953799971)
# 48838           Value  ...    (32.83968109300048, -83.62758034599966)
# 39044           Value  ...  (38.843840757000464, -106.13361092099967)
# 50006           Value  ...    (35.68094058000048, -85.77449091399967)
# 9924            Value  ...   (39.766910452000445, -86.14996019399968)
# 35676           Value  ...   (28.932040377000476, -81.92896053899966)
# 23668           Value  ...   (47.47531977900047, -100.11842104899966)
# 27344           Value  ...    (41.70828019300046, -71.52247031399963)
# 26937           Value  ...                    (18.220833, -66.590149)
# 47014           Value  ...     (44.6613195430005, -84.71439026999968)
#
#        ClassID TopicID QuestionID  DataValueTypeID  LocationID  \
# 14852       PA     PA1       Q047            VALUE          25
# 31511      OWS    OWS1       Q037            VALUE          50
# 10800      OWS    OWS1       Q037            VALUE          19
# 33809       PA     PA1       Q047            VALUE          54
# 21606      OWS    OWS1       Q036            VALUE          35
# 13008       PA     PA1       Q044            VALUE          23
# 1180        PA     PA1       Q044            VALUE           2
# 9761       OWS    OWS1       Q036            VALUE          18
# 7417       OWS    OWS1       Q036            VALUE          66
# 45192       PA     PA1       Q047            VALUE          55
# 2937        PA     PA1       Q047            VALUE           6
# 48838      OWS    OWS1       Q037            VALUE          13
# 39044       PA     PA1       Q047            VALUE           8
# 50006      OWS    OWS1       Q037            VALUE          47
# 9924        FV     FV1       Q019            VALUE          18
# 35676       FV     FV1       Q018            VALUE          12
# 23668       FV     FV1       Q018            VALUE          38
# 27344       PA     PA1       Q047            VALUE          44
# 26937      OWS    OWS1       Q036            VALUE          72
# 47014      OWS    OWS1       Q037            VALUE          26
#
#        StratificationCategory1                   Stratification1  \
# 14852                   Gender                              Male
# 31511              Age (years)                           18 - 24
# 10800              Age (years)                           55 - 64
# 33809                   Gender                            Female
# 21606                   Income                 $25,000 - $34,999
# 13008                Education                  College graduate
# 1180            Race/Ethnicity                Non-Hispanic White
# 9761                 Education  Some college or technical school
# 7417                    Income                 $35,000 - $49,999
# 45192              Age (years)                           55 - 64
# 2937               Age (years)                           55 - 64
# 48838                    Total                             Total
# 39044           Race/Ethnicity                Non-Hispanic Black
# 50006              Age (years)                           55 - 64
# 9924                    Income                 $15,000 - $24,999
# 35676              Age (years)                           55 - 64
# 23668                   Income                 $25,000 - $34,999
# 27344              Age (years)                       65 or older
# 26937           Race/Ethnicity                          Hispanic
# 47014              Age (years)                           25 - 34
#
#       StratificationCategoryId1 StratificationID1
# 14852                       GEN              MALE
# 31511                     AGEYR         AGEYR1824
# 10800                     AGEYR         AGEYR5564
# 33809                       GEN            FEMALE
# 21606                       INC           INC2535
# 13008                       EDU         EDUCOGRAD
# 1180                       RACE           RACEWHT
# 9761                        EDU          EDUCOTEC
# 7417                        INC           INC3550
# 45192                     AGEYR         AGEYR5564
# 2937                      AGEYR         AGEYR5564
# 48838                       OVR           OVERALL
# 39044                      RACE           RACEBLK
# 50006                     AGEYR         AGEYR5564
# 9924                        INC           INC1525
# 35676                     AGEYR         AGEYR5564
# 23668                       INC           INC2535
# 27344                     AGEYR       AGEYR65PLUS
# 26937                      RACE           RACEHIS
# 47014                     AGEYR         AGEYR2534
#
# [20 rows x 33 columns]

# %% [markdown]
# * YearStart/Year End - ranges from 2011 to 2016 (will be focusing only on 2014)
#
# * LocationAbbr - Location abbreviation (i.e. state abbreviation)
#
# * LocationDesc - full state name
#
# * Class/Topic- only focusing on obesity/weight status
#
# * Questions - only want
#        'Percent of adults aged 18 years and older who have obesity',
#        'Percent of adults aged 18 years and older who have an overweight classification'
#
# * Topic- only focusing on only percent of adults aged 18 years and older who are obese
#
# * StratificationCategory1 - Shows the category: Age, Income, Education, Gender, or Race/ethnicity
#
# * Stratificationy1 -  Shows more specific category info

# %% [markdown]
# ### Exploring the columns

# %%
#look at columns
obesity_in_US_df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
# find the years in the data
obesity_in_US_df['YearStart'].unique()
# Out:
# array([2011, 2012, 2014, 2013, 2015, 2016])

# %%
# find what states are in the data
obesity_in_US_df['LocationAbbr'].unique()
# Out:
# array(['AL', 'US', 'AK', 'AZ', 'AR', 'CA', 'CT', 'CO', 'DE', 'FL', 'DC',
#        'GA', 'GU', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME',
#        'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ',
#        'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC',
#        'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WV', 'WA', 'WI', 'WY', 'VI'],
#       dtype=object)

# %% [markdown]
# - eventually will get rid of GU, LA, VI

# %%
obesity_in_US_df['LocationDesc'].unique()
# Out:
# array(['Alabama', 'National', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Connecticut', 'Colorado', 'Delaware', 'Florida',
#        'District of Columbia', 'Georgia', 'Guam', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'West Virginia', 'Washington', 'Wisconsin', 'Wyoming',
#        'Virgin Islands'], dtype=object)

# %%
# explore the ages column
obesity_in_US_df['Age(years)'].unique()
# Out:
# array([nan, '18 - 24', '25 - 34', '35 - 44', '45 - 54', '55 - 64',
#        '65 or older'], dtype=object)

# %% [markdown]
# - There are 5 age groups

# %%
#explore the education column
obesity_in_US_df['Education'].unique()
# Out:
# array([nan, 'Less than high school', 'High school graduate',
#        'Some college or technical school', 'College graduate'],
#       dtype=object)

# %% [markdown]
# - there are 4 education levels

# %%
# explore the gender column
obesity_in_US_df['Gender'].unique()
# Out:
# array([nan, 'Male', 'Female'], dtype=object)

# %%
# explore the income column
obesity_in_US_df['Income'].unique()
# Out:
# array([nan, 'Less than $15,000', '$15,000 - $24,999', '$25,000 - $34,999',
#        '$35,000 - $49,999', '$50,000 - $74,999', '$75,000 or greater',
#        'Data not reported'], dtype=object)

# %% [markdown]
# - there are 6 income groups

# %%
# explore the race/ethnicity column
obesity_in_US_df['Race/Ethnicity'].unique()
# Out:
# array([nan, 'Non-Hispanic White', 'Non-Hispanic Black', 'Hispanic',
#        'Asian', 'Hawaiian/Pacific Islander',
#        'American Indian/Alaska Native', '2 or more races', 'Other'],
#       dtype=object)

# %% [markdown]
# - there are 7 race/ethnicities

# %%
# explore the stratification category 
obesity_in_US_df['StratificationCategory1'].unique()
# Out:
# array(['Total', 'Gender', 'Education', 'Age (years)', 'Income',
#        'Race/Ethnicity'], dtype=object)

# %%
# look at what a row consists of
obesity_in_US_df.iloc[12]
# Out:
# YearStart                                                                  2011
# YearEnd                                                                    2011
# LocationAbbr                                                                 AL
# LocationDesc                                                            Alabama
# Datasource                           Behavioral Risk Factor Surveillance System
# Class                                                   Obesity / Weight Status
# Topic                                                   Obesity / Weight Status
# Question                      Percent of adults aged 18 years and older who ...
# Data_Value_Unit                                                             NaN
# Data_Value_Type                                                           Value
# Data_Value                                                                 27.1
# Data_Value_Alt                                                             27.1
# Data_Value_Footnote_Symbol                                                  NaN
# Data_Value_Footnote                                                         NaN
# Low_Confidence_Limit                                                       24.9
# High_Confidence_Limit                                                      29.3
# Sample_Size                                                                2521
# Total                                                                       NaN
# Age(years)                                                          65 or older
# Education                                                                   NaN
# Gender                                                                      NaN
# Income                                                                      NaN
# Race/Ethnicity                                                              NaN
# GeoLocation                             (32.84057112200048, -86.63186076199969)
# ClassID                                                                     OWS
# TopicID                                                                    OWS1
# QuestionID                                                                 Q036
# DataValueTypeID                                                           VALUE
# LocationID                                                                    1
# StratificationCategory1                                             Age (years)
# Stratification1                                                     65 or older
# StratificationCategoryId1                                                 AGEYR
# StratificationID1                                                   AGEYR65PLUS
# Name: 12, dtype: object
